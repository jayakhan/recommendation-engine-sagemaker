# %%
# !pip install "scikit_learn==0.22.2.post1"
# Out:
# Collecting scikit_learn==0.22.2.post1
#   Downloading scikit_learn-0.22.2.post1-cp36-cp36m-manylinux1_x86_64.whl (7.1 MB)
#      |████████████████████████████████| 7.1 MB 509 kB/s eta 0:00:01███████████████████▊            | 4.4 MB 2.9 MB/s eta 0:00:01B/s eta 0:00:01 0:00:01a 0:00:01
# Requirement already satisfied: scipy>=0.17.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit_learn==0.22.2.post1) (1.5.3)
# Requirement already satisfied: numpy>=1.11.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit_learn==0.22.2.post1) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from scikit_learn==0.22.2.post1) (1.0.1)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Uninstalling scikit-learn-0.24.1:
#       Successfully uninstalled scikit-learn-0.24.1
# Successfully installed scikit-learn-0.22.2.post1
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import sagemaker
import seaborn as sns
import sklearn
from sklearn.datasets import fetch_20newsgroups
#from sklearn.datasets.twenty_newsgroups import strip_newsgroup_header, strip_newsgroup_quoting, strip_newsgroup_footer

# %%
newsgroups_train = fetch_20newsgroups(subset='train')['data']
newsgroups_test = fetch_20newsgroups(subset = 'test')['data']
NUM_TOPICS = 30
NUM_NEIGHBORS = 10
BUCKET = 'sagemaker-crsmids'
PREFIX = '20newsgroups'

# %%
# !pip3 uninstall scikit-learn -y
# !pip3 install scikit-learn==0.23.1

# %%
newsgroups_train[10]
# Out:
# 'From: irwin@cmptrc.lonestar.org (Irwin Arnstein)\nSubject: Re: Recommendation on Duc\nSummary: What\'s it worth?\nDistribution: usa\nExpires: Sat, 1 May 1993 05:00:00 GMT\nOrganization: CompuTrac Inc., Richardson TX\nKeywords: Ducati, GTS, How much? \nLines: 13\n\nI have a line on a Ducati 900GTS 1978 model with 17k on the clock.  Runs\nvery well, paint is the bronze/brown/orange faded out, leaks a bit of oil\nand pops out of 1st with hard accel.  The shop will fix trans and oil \nleak.  They sold the bike to the 1 and only owner.  They want $3495, and\nI am thinking more like $3K.  Any opinions out there?  Please email me.\nThanks.  It would be a nice stable mate to the Beemer.  Then I\'ll get\na jap bike and call myself Axis Motors!\n\n-- \n-----------------------------------------------------------------------\n"Tuba" (Irwin)      "I honk therefore I am"     CompuTrac-Richardson,Tx\nirwin@cmptrc.lonestar.org    DoD #0826          (R75/6)\n-----------------------------------------------------------------------\n'

# %%
def strip_newsgroup_header(text):
    """
    Given text in "news" format, strip the headers, by removing everything
    before the first blank line.
    Parameters
    ----------
    text : str
        The text from which to remove the signature block.
    """
    _before, _blankline, after = text.partition("\n\n")
    return after

# %%
def strip_newsgroup_quoting(text):
    """
    Given text in "news" format, strip lines beginning with the quote
    characters > or |, plus lines that often introduce a quoted section
    (for example, because they contain the string 'writes:'.)
    Parameters
    ----------
    text : str
        The text from which to remove the signature block.
    """
    good_lines = [line for line in text.split("\n") if not _QUOTE_RE.search(line)]
    return "\n".join(good_lines)

# %%
def strip_newsgroup_footer(text):
    """
    Given text in "news" format, attempt to remove a signature block.
    As a rough heuristic, we assume that signatures are set apart by either
    a blank line or a line made of hyphens, and that it is the last such line
    in the file (disregarding blank lines at the end).
    Parameters
    ----------
    text : str
        The text from which to remove the signature block.
    """
    lines = text.strip().split("\n")
    for line_num in range(len(lines) - 1, -1, -1):
        line = lines[line_num]
        if line.strip().strip("-") == "":
            break

    if line_num > 0:
        return "\n".join(lines[:line_num])
    else:
        return text

# %%
import re

_QUOTE_RE = re.compile(
    r"(writes in|writes:|wrote:|says:|said:" r"|^In article|^Quoted from|^\||^>)"
)

# %%
for i in range(len(newsgroups_train)):
    newsgroups_train[i] = strip_newsgroup_header(newsgroups_train[i])
    newsgroups_train[i] = strip_newsgroup_quoting(newsgroups_train[i])
    newsgroups_train[i] = strip_newsgroup_footer(newsgroups_train[i])

# %%
newsgroups_train[0:10]
# Out:
# ['Thanks,\n- IL\n   ---- brought to you by your neighborhood Lerxst ----\n\n\n\n\n',
#  "A fair number of brave souls who upgraded their SI clock oscillator have\nshared their experiences for this poll. Please send a brief message detailing\nyour experiences with the procedure. Top speed attained, CPU rated speed,\nadd on cards and adapters, heat sinks, hour of usage per day, floppy disk\nfunctionality with 800 and 1.4 m floppies are especially requested.\n\nI will be summarizing in the next two days, so please add to the network\nknowledge base if you have done the clock upgrade and haven't answered this\npoll. Thanks.",
#  'well folks, my mac plus finally gave up the ghost this weekend after\nstarting life as a 512k way back in 1985.  sooo, i\'m in the market for a\nnew machine a bit sooner than i intended to be...\n\ni\'m looking into picking up a powerbook 160 or maybe 180 and have a bunch\nof questions that (hopefully) somebody can answer:\n\n* does anybody know any dirt on when the next round of powerbook\nintroductions are expected?  i\'d heard the 185c was supposed to make an\nappearence "this summer" but haven\'t heard anymore on it - and since i\ndon\'t have access to macleak, i was wondering if anybody out there had\nmore info...\n\n* has anybody heard rumors about price drops to the powerbook line like the\nones the duo\'s just went through recently?\n\n* what\'s the impression of the display on the 180?  i could probably swing\na 180 if i got the 80Mb disk rather than the 120, but i don\'t really have\na feel for how much "better" the display is (yea, it looks great in the\nstore, but is that all "wow" or is it really that good?).  could i solicit\nsome opinions of people who use the 160 and 180 day-to-day on if its worth\ntaking the disk size and money hit to get the active display?  (i realize\nthis is a real subjective question, but i\'ve only played around with the\nmachines in a computer store breifly and figured the opinions of somebody\nwho actually uses the machine daily might prove helpful).\n\n* how well does hellcats perform?  ;)\n\nthanks a bunch in advance for any info - if you could email, i\'ll post a\nsummary (news reading time is at a premium with finals just around the\ncorner... :( )\n--\nTom Willis  \\  twillis@ecn.purdue.edu    \\    Purdue Electrical Engineering',
#  "Do you have Weitek's address/phone number?  I'd like to get some information\nabout this chip.\n",
#  "From article <C5owCB.n3p@world.std.com>, by tombaker@world.std.com (Tom A Baker):\n\n\nMy understanding is that the 'expected errors' are basically\nknown bugs in the warning system software - things are checked\nthat don't have the right values in yet because they aren't\nset till after launch, and suchlike. Rather than fix the code\nand possibly introduce new bugs, they just tell the crew\n'ok, if you see a warning no. 213 before liftoff, ignore it'.",
#  'Of course.  The term must be rigidly defined in any bill.\n\n\nI doubt she uses this term for that.  You are using a quote allegedly\nfrom her, can you back it up?\n\n\n\n\nI read the article as presenting first an argument about weapons of mass\ndestruction (as commonly understood) and then switching to other topics.\nThe first point evidently was to show that not all weapons should be\nallowed, and then the later analysis was, given this understanding, to\nconsider another class.\n\n\n\n',
#  'There were a few people who responded to my request for info on\ntreatment for astrocytomas through email, whom I couldn\'t thank\ndirectly because of mail-bouncing probs (Sean, Debra, and Sharon).  So\nI thought I\'d publicly thank everyone.\n\nThanks! \n\n(I\'m sure glad I accidentally hit "rn" instead of "rm" when I was\ntrying to delete a file last September. "Hmmm... \'News?\' What\'s\nthis?"....)',
#  'ALL this shows is that YOU don\'t know much about SCSI.\n\nSCSI-1 {with a SCSI-1 controler chip} range is indeed 0-5MB/s\nand that is ALL you have right about SCSI\nSCSI-1 {With a SCSI-2 controller chip}: 4-6MB/s with 10MB/s burst {8-bit}\n Note the INCREASE in SPEED, the Mac Quadra uses this version of SCSI-1\n so it DOES exist. Some PC use this set up too.\nSCSI-2 {8-bit/SCSI-1 mode}:          4-6MB/s with 10MB/s burst\nSCSI-2 {16-bit/wide or fast mode}:  8-12MB/s with 20MB/s burst\nSCSI-2 {32-bit/wide AND fast}:     15-20MB/s with 40MB/s burst\n \nBy your OWN data the "Although SCSI is twice as fast as ESDI" is correct\nWith a SCSI-2 controller chip SCSI-1 can reach 10MB/s which is indeed\n"20% faster than IDE" {120% of 8.3 is 9.96}. ALL these SCSI facts have been\nposted to this newsgroup in my Mac & IBM info sheet {available by FTP on \nsumex-aim.stanford.edu (36.44.0.6) in the info-mac/report as \nmac-ibm-compare[version #].txt (It should be 173 but 161 may still be there)}\n\nPart of this problem is both Mac and IBM PC are inconsiant about what SCSI\nis which.  Though it is WELL documented that the Quadra has a SCSI-2 chip\nan Apple salesperson said "it uses a fast SCSI-1 chip" {Not at a 6MB/s,\n10MB/s burst it does not. SCSI-1 is 5MB/s maximum synchronous and Quadra\nuses ANsynchronous SCSI which is SLOWER}  It seems that Mac and IBM see\nSCSI-1 interface and think \'SCSI-1\' when it maybe a SCSI-1 interface driven\nin the machine by a SCSi-2 controller chip in 8-bit mode {Which is MUCH\nFASTER then true SCSI-1 can go}.',
#  'I have win 3.0 and downloaded several icons and BMP\'s but I can\'t figure out\nhow to change the "wallpaper" or use the icons.  Any help would be appreciated.\n\n\nThanx,\n\n-Brando',
#  "I've had the board for over a year, and it does work with Diskdoubler,\nbut not with Autodoubler, due to a licensing problem with Stac Technologies,\nthe owners of the board's compression technology. (I'm writing this\nfrom memory; I've lost the reference. Please correct me if I'm wrong.)\n\nUsing the board, I've had problems with file icons being lost, but it's\nhard to say whether it's the board's fault or something else; however,\nif I decompress the troubled file and recompress it without the board,\nthe icon usually reappears. Because of the above mentioned licensing\nproblem, the freeware expansion utility DD Expand will not decompress\na board-compressed file unless you have the board installed.\n\nSince Stac has its own product now, it seems unlikely that the holes\nin Autodoubler/Diskdoubler related to the board will be fixed.\nWhich is sad, and makes me very reluctant to buy Stac's product since\nthey're being so stinky. (But hey, that's competition.)\n-- "]

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('wordnet')
from nltk import word_tokenize          
from nltk.stem import WordNetLemmatizer 
import re
token_pattern = re.compile(r"(?u)\b\w\w+\b")
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, doc):
        return [self.wnl.lemmatize(t) for t in word_tokenize(doc) if len(t) >= 2 and re.match("[a-z].*",t) 
                and re.match(token_pattern, t)]
# Out:
# Requirement already satisfied: nltk in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (3.4.4)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from nltk) (1.15.0)
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: '/home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/numpy-1.19.5.dist-info/METADATA'
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /home/ec2-user/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
import time
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
vocab_size = 2000
print('Tokenizing and counting, this may take a few minutes...')
start_time = time.time()
vectorizer = CountVectorizer(input='content', analyzer='word', stop_words='english',
                             tokenizer=LemmaTokenizer(), max_features=vocab_size, max_df=0.95, min_df=2)
vectors = vectorizer.fit_transform(newsgroups_train)
vocab_list = vectorizer.get_feature_names()
print('vocab size:', len(vocab_list))

# random shuffle
idx = np.arange(vectors.shape[0])
newidx = np.random.permutation(idx) # this will be the labels fed into the KNN model for training
# Need to store these permutations:

vectors = vectors[newidx]

print('Done. Time elapsed: {:.2f}s'.format(time.time() - start_time))
# Out:
# Tokenizing and counting, this may take a few minutes...
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/sklearn/feature_extraction/text.py:391: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ha', 'le', 'u', 'wa'] not in stop_words.
#   self._stop_words_id = id(self.stop_words)
# vocab size: 2000
# Done. Time elapsed: 39.02s

# %%
import scipy.sparse as sparse
vectors = sparse.csr_matrix(vectors, dtype=np.float32)
print(type(vectors), vectors.dtype)
# Out:
# <class 'scipy.sparse.csr.csr_matrix'> float32

# %%
# Convert data into training and validation data
n_train = int(0.8 * vectors.shape[0])

# split train and test
train_vectors = vectors[:n_train, :]
val_vectors = vectors[n_train:, :]

# further split test set into validation set (val_vectors) and test  set (test_vectors)

print(train_vectors.shape,val_vectors.shape)
# Out:
# (9051, 2000) (2263, 2000)

# %%
def split_convert_upload(sparray, bucket, prefix, fname_template='data_part{}.pbr', n_parts=2):
    import io
    import boto3
    import sagemaker.amazon.common as smac
    
    chunk_size = sparray.shape[0]// n_parts
    for i in range(n_parts):

        # Calculate start and end indices
        start = i*chunk_size
        end = (i+1)*chunk_size
        if i+1 == n_parts:
            end = sparray.shape[0]
        
        # Convert to record protobuf
        buf = io.BytesIO()
        smac.write_spmatrix_to_sparse_tensor(array=sparray[start:end], file=buf, labels=None)
        buf.seek(0)
        
        # Upload to s3 location specified by bucket and prefix
        fname = os.path.join(prefix, fname_template.format(i))
        boto3.resource('s3').Bucket(bucket).Object(fname).upload_fileobj(buf)
        print('Uploaded data to s3://{}'.format(os.path.join(bucket, fname)))
split_convert_upload(train_vectors, bucket=bucket, prefix=train_prefix, fname_template='train_part{}.pbr', n_parts=8)
split_convert_upload(val_vectors, bucket=bucket, prefix=val_prefix, fname_template='val_part{}.pbr', n_parts=1)
prefix = PREFIX

train_prefix = os.path.join(prefix, 'train')
val_prefix = os.path.join(prefix, 'val')
output_prefix = os.path.join(prefix, 'output')

s3_train_data = os.path.join('s3://', bucket, train_prefix)
s3_val_data = os.path.join('s3://', bucket, val_prefix)
output_path = os.path.join('s3://', bucket, output_prefix)
print('Training set location', s3_train_data)
print('Validation set location', s3_val_data)
print('Trained model will be saved at', output_path)
# Out:
# Uploaded data to s3://sagemaker-crsmids/20newsgroups/train/train_part0.pbr
# Uploaded data to s3://sagemaker-crsmids/20newsgroups/train/train_part1.pbr
# Uploaded data to s3://sagemaker-crsmids/20newsgroups/train/train_part2.pbr
# Uploaded data to s3://sagemaker-crsmids/20newsgroups/train/train_part3.pbr
# Uploaded data to s3://sagemaker-crsmids/20newsgroups/train/train_part4.pbr
# Uploaded data to s3://sagemaker-crsmids/20newsgroups/train/train_part5.pbr
# Uploaded data to s3://sagemaker-crsmids/20newsgroups/train/train_part6.pbr
# Uploaded data to s3://sagemaker-crsmids/20newsgroups/train/train_part7.pbr
# Uploaded data to s3://sagemaker-crsmids/20newsgroups/val/val_part0.pbr
# Training set location s3://sagemaker-crsmids/20newsgroups/train
# Validation set location s3://sagemaker-crsmids/20newsgroups/val
# Trained model will be saved at s3://sagemaker-crsmids/20newsgroups/output

# %%
import boto3
from sagemaker.amazon.amazon_estimator import get_image_uri
container = get_image_uri(boto3.Session().region_name, 'ntm')
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.

# %%
sess = sagemaker.Session()
ntm = sagemaker.estimator.Estimator(container,
                                    role, 
                                    train_instance_count=2, 
                                    train_instance_type='ml.c4.xlarge',
                                    output_path=output_path,
                                    sagemaker_session=sess)
# Out:
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.

# %%
ntm.set_hyperparameters(num_topics=NUM_TOPICS, feature_dim=vocab_size, mini_batch_size=128, 
                        epochs=100, num_patience_epochs=5, tolerance=0.001)

# %%
from sagemaker.session import s3_input
s3_train = s3_input(s3_train_data, distribution='ShardedByS3Key') 
ntm.fit({'train': s3_train, 'test': s3_val_data})
# Out:
# The class sagemaker.session.s3_input has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-11-13 21:27:28 Starting - Starting the training job...
# 2021-11-13 21:27:52 Starting - Launching requested ML instancesProfilerReport-1636838848: InProgress
# ...
# 2021-11-13 21:28:19 Starting - Preparing the instances for training............
# 2021-11-13 21:30:24 Downloading - Downloading input data...
# 2021-11-13 21:30:55 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python3.7/site-packages/jsonref.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping, MutableMapping, Sequence
# [11/13/2021 21:30:54 INFO 140519838742336] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/default-input.json: {'encoder_layers': 'auto', 'mini_batch_size': '256', 'epochs': '50', 'encoder_layers_activation': 'sigmoid', 'optimizer': 'adadelta', 'tolerance': '0.001', 'num_patience_epochs': '3', 'batch_norm': 'false', 'rescale_gradient': '1.0', 'clip_gradient': 'Inf', 'weight_decay': '0.0', 'learning_rate': '0.01', 'sub_sample': '1.0', '_tuning_objective_metric': '', '_data_format': 'record', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_kvstore': 'auto_gpu'}
# [11/13/2021 21:30:54 INFO 140519838742336] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '2000', 'num_topics': '30', 'num_patience_epochs': '5', 'epochs': '100', 'tolerance': '0.001', 'mini_batch_size': '128'}
# [11/13/2021 21:30:54 INFO 140519838742336] Final configuration: {'encoder_layers': 'auto', 'mini_batch_size': '128', 'epochs': '100', 'encoder_layers_activation': 'sigmoid', 'optimizer': 'adadelta', 'tolerance': '0.001', 'num_patience_epochs': '5', 'batch_norm': 'false', 'rescale_gradient': '1.0', 'clip_gradient': 'Inf', 'weight_decay': '0.0', 'learning_rate': '0.01', 'sub_sample': '1.0', '_tuning_objective_metric': '', '_data_format': 'record', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_kvstore': 'auto_gpu', 'feature_dim': '2000', 'num_topics': '30'}
# [11/13/2021 21:30:54 INFO 140519838742336] nvidia-smi: took 0.028 seconds to run.
# [11/13/2021 21:30:54 INFO 140519838742336] nvidia-smi identified 0 GPUs.
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python3.7/site-packages/jsonref.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping, MutableMapping, Sequence
# [11/13/2021 21:30:58 INFO 140380735153984] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/default-input.json: {'encoder_layers': 'auto', 'mini_batch_size': '256', 'epochs': '50', 'encoder_layers_activation': 'sigmoid', 'optimizer': 'adadelta', 'tolerance': '0.001', 'num_patience_epochs': '3', 'batch_norm': 'false', 'rescale_gradient': '1.0', 'clip_gradient': 'Inf', 'weight_decay': '0.0', 'learning_rate': '0.01', 'sub_sample': '1.0', '_tuning_objective_metric': '', '_data_format': 'record', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_kvstore': 'auto_gpu'}
# [11/13/2021 21:30:58 INFO 140380735153984] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '2000', 'num_topics': '30', 'num_patience_epochs': '5', 'epochs': '100', 'tolerance': '0.001', 'mini_batch_size': '128'}
# [11/13/2021 21:30:58 INFO 140380735153984] Final configuration: {'encoder_layers': 'auto', 'mini_batch_size': '128', 'epochs': '100', 'encoder_layers_activation': 'sigmoid', 'optimizer': 'adadelta', 'tolerance': '0.001', 'num_patience_epochs': '5', 'batch_norm': 'false', 'rescale_gradient': '1.0', 'clip_gradient': 'Inf', 'weight_decay': '0.0', 'learning_rate': '0.01', 'sub_sample': '1.0', '_tuning_objective_metric': '', '_data_format': 'record', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_kvstore': 'auto_gpu', 'feature_dim': '2000', 'num_topics': '30'}
# [11/13/2021 21:30:58 INFO 140380735153984] nvidia-smi: took 0.028 seconds to run.
# [11/13/2021 21:30:58 INFO 140380735153984] nvidia-smi identified 0 GPUs.
# [11/13/2021 21:30:59 INFO 140519838742336] Launching parameter server for role server
# [11/13/2021 21:30:59 INFO 140519838742336] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-74-87.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'ntm-2021-11-13-21-27-28-416', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/ntm-2021-11-13-21-27-28-416', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/fa9b3f32-6857-4ad6-bc49-4408485c5ac1', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/4918fba7-a0e5-423a-9b73-70181f04d7c1', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/4918fba7-a0e5-423a-9b73-70181f04d7c1', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [11/13/2021 21:30:59 INFO 140519838742336] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-74-87.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'ntm-2021-11-13-21-27-28-416', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/ntm-2021-11-13-21-27-28-416', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/fa9b3f32-6857-4ad6-bc49-4408485c5ac1', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/4918fba7-a0e5-423a-9b73-70181f04d7c1', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/4918fba7-a0e5-423a-9b73-70181f04d7c1', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.0.118.150', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [11/13/2021 21:30:59 INFO 140519838742336] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-74-87.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'ntm-2021-11-13-21-27-28-416', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/ntm-2021-11-13-21-27-28-416', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/fa9b3f32-6857-4ad6-bc49-4408485c5ac1', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/4918fba7-a0e5-423a-9b73-70181f04d7c1', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/4918fba7-a0e5-423a-9b73-70181f04d7c1', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.118.150', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# Process 35 is a shell:server.
# Process 1 is a worker.
# [11/13/2021 21:30:59 INFO 140519838742336] Using default worker.
# [11/13/2021 21:31:00 INFO 140519838742336] Checkpoint loading and saving are disabled.
# [2021-11-13 21:31:00.018] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [11/13/2021 21:31:00 INFO 140519838742336] Initializing
# [11/13/2021 21:31:00 INFO 140519838742336] None
# [11/13/2021 21:31:00 INFO 140519838742336] vocab.txt
# [11/13/2021 21:31:00 INFO 140519838742336] Vocab file is not provided
# [11/13/2021 21:31:00 INFO 140519838742336] Number of GPUs being used: 0
# [11/13/2021 21:31:00 INFO 140519838742336] Create Store: dist_async
# [11/13/2021 21:30:59 INFO 140380735153984] Launching parameter server for role scheduler
# [11/13/2021 21:30:59 INFO 140380735153984] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-118-150.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'ntm-2021-11-13-21-27-28-416', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/ntm-2021-11-13-21-27-28-416', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/39b29a10-dae9-4f69-a8ac-d35176b6da47', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/358dc22f-22af-4e8e-906a-6e19bab2e93d', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/358dc22f-22af-4e8e-906a-6e19bab2e93d', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [11/13/2021 21:30:59 INFO 140380735153984] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-118-150.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'ntm-2021-11-13-21-27-28-416', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/ntm-2021-11-13-21-27-28-416', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/39b29a10-dae9-4f69-a8ac-d35176b6da47', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/358dc22f-22af-4e8e-906a-6e19bab2e93d', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/358dc22f-22af-4e8e-906a-6e19bab2e93d', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.0.118.150', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [11/13/2021 21:30:59 INFO 140380735153984] Launching parameter server for role server
# [11/13/2021 21:30:59 INFO 140380735153984] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-118-150.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'ntm-2021-11-13-21-27-28-416', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/ntm-2021-11-13-21-27-28-416', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/39b29a10-dae9-4f69-a8ac-d35176b6da47', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/358dc22f-22af-4e8e-906a-6e19bab2e93d', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/358dc22f-22af-4e8e-906a-6e19bab2e93d', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [11/13/2021 21:30:59 INFO 140380735153984] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-118-150.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'ntm-2021-11-13-21-27-28-416', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/ntm-2021-11-13-21-27-28-416', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/39b29a10-dae9-4f69-a8ac-d35176b6da47', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/358dc22f-22af-4e8e-906a-6e19bab2e93d', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/358dc22f-22af-4e8e-906a-6e19bab2e93d', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.0.118.150', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# [11/13/2021 21:30:59 INFO 140380735153984] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-118-150.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'ntm-2021-11-13-21-27-28-416', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/ntm-2021-11-13-21-27-28-416', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/39b29a10-dae9-4f69-a8ac-d35176b6da47', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'MXNET_STORAGE_FALLBACK_LOG_VERBOSE': '0', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/358dc22f-22af-4e8e-906a-6e19bab2e93d', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/358dc22f-22af-4e8e-906a-6e19bab2e93d', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.118.150', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '2', 'DMLC_NUM_WORKER': '2'}
# Process 34 is a shell:scheduler.
# Process 35 is a shell:server.
# Process 1 is a worker.
# [11/13/2021 21:30:59 INFO 140380735153984] Using default worker.
# [11/13/2021 21:30:59 INFO 140380735153984] Checkpoint loading and saving are disabled.
# [2021-11-13 21:30:59.849] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [11/13/2021 21:30:59 INFO 140380735153984] Initializing
# [11/13/2021 21:30:59 INFO 140380735153984] None
# [11/13/2021 21:30:59 INFO 140380735153984] vocab.txt
# [11/13/2021 21:30:59 INFO 140380735153984] Vocab file is not provided
# [11/13/2021 21:30:59 INFO 140380735153984] Number of GPUs being used: 0
# [11/13/2021 21:30:59 INFO 140380735153984] Create Store: dist_async
# #metrics {"StartTime": 1636839060.575404, "EndTime": 1636839060.575438, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2021-11-13 21:31:00.575] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 732, "num_examples": 1, "num_bytes": 27924}
# [11/13/2021 21:31:00 INFO 140380735153984]
# [11/13/2021 21:31:00 INFO 140380735153984] # Starting training for epoch 1
# #metrics {"StartTime": 1636839060.5754626, "EndTime": 1636839060.5754898, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2021-11-13 21:31:00.575] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 562, "num_examples": 1, "num_bytes": 28308}
# [11/13/2021 21:31:00 INFO 140519838742336]
# [11/13/2021 21:31:00 INFO 140519838742336] # Starting training for epoch 1
# [2021-11-13 21:31:02.115] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 2, "duration": 1538, "num_examples": 36, "num_bytes": 1038268}
# [11/13/2021 21:31:02 INFO 140519838742336] # Finished training epoch 1 on 4527 examples from 36 batches, each of size 128.
# [11/13/2021 21:31:02 INFO 140519838742336] Metrics for Training:
# [11/13/2021 21:31:02 INFO 140519838742336] Loss (name: value) total: 6.957811527782017
# [11/13/2021 21:31:02 INFO 140519838742336] Loss (name: value) kld: 0.023970360998646356
# [11/13/2021 21:31:02 INFO 140519838742336] Loss (name: value) recons: 6.933841162257725
# [11/13/2021 21:31:02 INFO 140519838742336] Loss (name: value) logppx: 6.957811527782017
# [11/13/2021 21:31:02 INFO 140519838742336] #quality_metric: host=algo-2, epoch=1, train total_loss <loss>=6.957811527782017
# [11/13/2021 21:31:02 INFO 140519838742336] Timing: train: 1.55s, val: 0.00s, epoch: 1.55s
# [11/13/2021 21:31:02 INFO 140519838742336] #progress_metric: host=algo-2, completed 1.0 % of epochs
# #metrics {"StartTime": 1636839060.575967, "EndTime": 1636839062.1232266, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4527.0, "count": 1, "min": 4527, "max": 4527}, "Total Batches Seen": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Max Records Seen Between Resets": {"sum": 4527.0, "count": 1, "min": 4527, "max": 4527}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 4527.0, "count": 1, "min": 4527, "max": 4527}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [11/13/2021 21:31:02 INFO 140519838742336] #throughput_metric: host=algo-2, train throughput=2924.907648647187 records/second
# [11/13/2021 21:31:02 INFO 140519838742336]
# [11/13/2021 21:31:02 INFO 140519838742336] # Starting training for epoch 2
# [2021-11-13 21:31:02.037] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 2, "duration": 1461, "num_examples": 36, "num_bytes": 1059472}
# [11/13/2021 21:31:02 INFO 140380735153984] # Finished training epoch 1 on 4524 examples from 36 batches, each of size 128.
# [11/13/2021 21:31:02 INFO 140380735153984] Metrics for Training:
# [11/13/2021 21:31:02 INFO 140380735153984] Loss (name: value) total: 6.974809454547034
# [11/13/2021 21:31:02 INFO 140380735153984] Loss (name: value) kld: 0.017609400778181024
# [11/13/2021 21:31:02 INFO 140380735153984] Loss (name: value) recons: 6.957200076844957
# [11/13/2021 21:31:02 INFO 140380735153984] Loss (name: value) logppx: 6.974809454547034
# [11/13/2021 21:31:02 INFO 140380735153984] #quality_metric: host=algo-1, epoch=1, train total_loss <loss>=6.974809454547034
# [11/13/2021 21:31:02 INFO 140380735153984] Timing: train: 1.47s, val: 0.00s, epoch: 1.47s
# [11/13/2021 21:31:02 INFO 140380735153984] #progress_metric: host=algo-1, completed 1.0 % of epochs
# #metrics {"StartTime": 1636839060.5758781, "EndTime": 1636839062.043086, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 4524.0, "count": 1, "min": 4524, "max": 4524}, "Total Batches Seen": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Max Records Seen Between Resets": {"sum": 4524.0, "count": 1, "min": 4524, "max": 4524}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 4524.0, "count": 1, "min": 4524, "max": 4524}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [11/13/2021 21:31:02 INFO 140380735153984] #throughput_metric: host=algo-1, train throughput=3083.1034827556905 records/second
# [11/13/2021 21:31:02 INFO 140380735153984]
# [11/13/2021 21:31:02 INFO 140380735153984] # Starting training for epoch 2
# [2021-11-13 21:31:03.593] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 1549, "num_examples": 36, "num_bytes": 1059472}
# [11/13/2021 21:31:03 INFO 140380735153984] # Finished training epoch 2 on 4524 examples from 36 batches, each of size 128.
# [11/13/2021 21:31:03 INFO 140380735153984] Metrics for Training:
# [11/13/2021 21:31:03 INFO 140380735153984] Loss (name: value) total: 6.880677150355445
# [11/13/2021 21:31:03 INFO 140380735153984] Loss (name: value) kld: 0.0021370806546959407
# [11/13/2021 21:31:03 INFO 140380735153984] Loss (name: value) recons: 6.878540065553453
# [11/13/2021 21:31:03 INFO 140380735153984] Loss (name: value) logppx: 6.880677150355445
# [11/13/2021 21:31:03 INFO 140380735153984] #quality_metric: host=algo-1, epoch=2, train total_loss <loss>=6.880677150355445
# [11/13/2021 21:31:03 INFO 140380735153984] Timing: train: 1.55s, val: 0.01s, epoch: 1.56s
# [11/13/2021 21:31:03 INFO 140380735153984] #progress_metric: host=algo-1, completed 2.0 % of epochs
# #metrics {"StartTime": 1636839062.043401, "EndTime": 1636839063.6005297, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 9048.0, "count": 1, "min": 9048, "max": 9048}, "Total Batches Seen": {"sum": 72.0, "count": 1, "min": 72, "max": 72}, "Max Records Seen Between Resets": {"sum": 4524.0, "count": 1, "min": 4524, "max": 4524}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 4524.0, "count": 1, "min": 4524, "max": 4524}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [11/13/2021 21:31:03 INFO 140380735153984] #throughput_metric: host=algo-1, train throughput=2905.0962570480046 records/second
# [11/13/2021 21:31:03 INFO 140380735153984]
# [11/13/2021 21:31:03 INFO 140380735153984] # Starting training for epoch 3
# [2021-11-13 21:31:03.391] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 1264, "num_examples": 36, "num_bytes": 1038268}
# [11/13/2021 21:31:03 INFO 140519838742336] # Finished training epoch 2 on 4527 examples from 36 batches, each of size 128.
# [11/13/2021 21:31:03 INFO 140519838742336] Metrics for Training:
# [11/13/2021 21:31:03 INFO 140519838742336] Loss (name: value) total: 6.866222891542646
# [11/13/2021 21:31:03 INFO 140519838742336] Loss (name: value) kld: 0.0020559609207945564
# [11/13/2021 21:31:03 INFO 140519838742336] Loss (name: value) recons: 6.864166941907671
# [11/13/2021 21:31:03 INFO 140519838742336] Loss (name: value) logppx: 6.866222891542646
# [11/13/2021 21:31:03 INFO 140519838742336] #quality_metric: host=algo-2, epoch=2, train total_loss <loss>=6.866222891542646
# [11/13/2021 21:31:03 INFO 140519838742336] Timing: train: 1.27s, val: 0.00s, epoch: 1.27s
# [11/13/2021 21:31:03 INFO 140519838742336] #progress_metric: host=algo-2, completed 2.0 % of epochs
# #metrics {"StartTime": 1636839062.124071, "EndTime": 1636839063.395371, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training", "epoch": 1, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 9054.0, "count": 1, "min": 9054, "max": 9054}, "Total Batches Seen": {"sum": 72.0, "count": 1, "min": 72, "max": 72}, "Max Records Seen Between Resets": {"sum": 4527.0, "count": 1, "min": 4527, "max": 4527}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 4.0, "count": 1, "min": 4, "max": 4}, "Number of Records Since Last Reset": {"sum": 4527.0, "count": 1, "min": 4527, "max": 4527}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [11/13/2021 21:31:03 INFO 140519838742336] #throughput_metric: host=algo-2, train throughput=3560.47296072618 records/second
# [11/13/2021 21:31:03 INFO 140519838742336]
# [11/13/2021 21:31:03 INFO 140519838742336] # Starting training for epoch 3
# [2021-11-13 21:31:05.152] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 1544, "num_examples": 36, "num_bytes": 1059472}
# [11/13/2021 21:31:05 INFO 140380735153984] # Finished training epoch 3 on 4524 examples from 36 batches, each of size 128.
# [11/13/2021 21:31:05 INFO 140380735153984] Metrics for Training:
# [11/13/2021 21:31:05 INFO 140380735153984] Loss (name: value) total: 6.875515739123027
# [11/13/2021 21:31:05 INFO 140380735153984] Loss (name: value) kld: 0.005280881304416753
# [11/13/2021 21:31:05 INFO 140380735153984] Loss (name: value) recons: 6.870234860314263
# [11/13/2021 21:31:05 INFO 140380735153984] Loss (name: value) logppx: 6.875515739123027
# [11/13/2021 21:31:05 INFO 140380735153984] #quality_metric: host=algo-1, epoch=3, train total_loss <loss>=6.875515739123027
# [11/13/2021 21:31:05 INFO 140380735153984] Timing: train: 1.55s, val: 0.00s, epoch: 1.56s
# [11/13/2021 21:31:05 INFO 140380735153984] #progress_metric: host=algo-1, completed 3.0 % of epochs
# #metrics {"StartTime": 1636839063.6007688, "EndTime": 1636839065.158471, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 13572.0, "count": 1, "min": 13572, "max": 13572}, "Total Batches Seen": {"sum": 108.0, "count": 1, "min": 108, "max": 108}, "Max Records Seen Between Resets": {"sum": 4524.0, "count": 1, "min": 4524, "max": 4524}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 4524.0, "count": 1, "min": 4524, "max": 4524}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [11/13/2021 21:31:05 INFO 140380735153984] #throughput_metric: host=algo-1, train throughput=2903.9971938021226 records/second
# [11/13/2021 21:31:05 INFO 140380735153984]
# [11/13/2021 21:31:05 INFO 140380735153984] # Starting training for epoch 4
# [2021-11-13 21:31:07.032] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 11, "duration": 1871, "num_examples": 36, "num_bytes": 1059472}
# [11/13/2021 21:31:07 INFO 140380735153984] # Finished training epoch 4 on 4524 examples from 36 batches, each of size 128.
# [11/13/2021 21:31:07 INFO 140380735153984] Metrics for Training:
# [11/13/2021 21:31:07 INFO 140380735153984] Loss (name: value) total: 6.873640656471252
# [11/13/2021 21:31:07 INFO 140380735153984] Loss (name: value) kld: 0.006723968557909959
# [11/13/2021 21:31:07 INFO 140380735153984] Loss (name: value) recons: 6.866916682985094
# [11/13/2021 21:31:07 INFO 140380735153984] Loss (name: value) logppx: 6.873640656471252
# [11/13/2021 21:31:07 INFO 140380735153984] #quality_metric: host=algo-1, epoch=4, train total_loss <loss>=6.873640656471252
# [11/13/2021 21:31:07 INFO 140380735153984] Timing: train: 1.87s, val: 0.00s, epoch: 1.88s
# [11/13/2021 21:31:07 INFO 140380735153984] #progress_metric: host=algo-1, completed 4.0 % of epochs
# #metrics {"StartTime": 1636839065.15878, "EndTime": 1636839067.037149, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 18096.0, "count": 1, "min": 18096, "max": 18096}, "Total Batches Seen": {"sum": 144.0, "count": 1, "min": 144, "max": 144}, "Max Records Seen Between Resets": {"sum": 4524.0, "count": 1, "min": 4524, "max": 4524}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 4524.0, "count": 1, "min": 4524, "max": 4524}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [11/13/2021 21:31:07 INFO 140380735153984] #throughput_metric: host=algo-1, train throughput=2408.2965706674913 records/second
# [11/13/2021 21:31:07 INFO 140380735153984]
# [11/13/2021 21:31:07 INFO 140380735153984] # Starting training for epoch 5
# [2021-11-13 21:31:04.885] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 8, "duration": 1489, "num_examples": 36, "num_bytes": 1038268}
# [11/13/2021 21:31:04 INFO 140519838742336] # Finished training epoch 3 on 4527 examples from 36 batches, each of size 128.
# [11/13/2021 21:31:04 INFO 140519838742336] Metrics for Training:
# [11/13/2021 21:31:04 INFO 140519838742336] Loss (name: value) total: 6.86092867453893
# [11/13/2021 21:31:04 INFO 140519838742336] Loss (name: value) kld: 0.004619522846446166
# [11/13/2021 21:31:04 INFO 140519838742336] Loss (name: value) recons: 6.856309155623118
# [11/13/2021 21:31:04 INFO 140519838742336] Loss (name: value) logppx: 6.86092867453893
# [11/13/2021 21:31:04 INFO 140519838742336] #quality_metric: host=algo-2, epoch=3, train total_loss <loss>=6.86092867453893
# [11/13/2021 21:31:04 INFO 140519838742336] Timing: train: 1.49s, val: 0.00s, epoch: 1.50s
# [11/13/2021 21:31:04 INFO 140519838742336] #progress_metric: host=algo-2, completed 3.0 % of epochs
# #metrics {"StartTime": 1636839063.3956895, "EndTime": 1636839064.8931627, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training", "epoch": 2, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 13581.0, "count": 1, "min": 13581, "max": 13581}, "Total Batches Seen": {"sum": 108.0, "count": 1, "min": 108, "max": 108}, "Max Records Seen Between Resets": {"sum": 4527.0, "count": 1, "min": 4527, "max": 4527}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 6.0, "count": 1, "min": 6, "max": 6}, "Number of Records Since Last Reset": {"sum": 4527.0, "count": 1, "min": 4527, "max": 4527}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [11/13/2021 21:31:04 INFO 140519838742336] #throughput_metric: host=algo-2, train throughput=3022.78729448354 records/second
# [11/13/2021 21:31:04 INFO 140519838742336]
# [11/13/2021 21:31:04 INFO 140519838742336] # Starting training for epoch 4
# [2021-11-13 21:31:07.133] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 11, "duration": 2238, "num_examples": 36, "num_bytes": 1038268}
# [11/13/2021 21:31:07 INFO 140519838742336] # Finished training epoch 4 on 4527 examples from 36 batches, each of size 128.
# [11/13/2021 21:31:07 INFO 140519838742336] Metrics for Training:
# [11/13/2021 21:31:07 INFO 140519838742336] Loss (name: value) total: 6.859765284591251
# [11/13/2021 21:31:07 INFO 140519838742336] Loss (name: value) kld: 0.00742341871955432
# [11/13/2021 21:31:07 INFO 140519838742336] Loss (name: value) recons: 6.852341837353176
# [11/13/2021 21:31:07 INFO 140519838742336] Loss (name: value) logppx: 6.859765284591251
# [11/13/2021 21:31:07 INFO 140519838742336] #quality_metric: host=algo-2, epoch=4, train total_loss <loss>=6.859765284591251
# [11/13/2021 21:31:07 INFO 140519838742336] Timing: train: 2.24s, val: 0.00s, epoch: 2.24s
# [11/13/2021 21:31:07 INFO 140519838742336] #progress_metric: host=algo-2, completed 4.0 % of epochs
# #metrics {"StartTime": 1636839064.8934715, "EndTime": 1636839067.1382914, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training", "epoch": 3, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 18108.0, "count": 1, "min": 18108, "max": 18108}, "Total Batches Seen": {"sum": 144.0, "count": 1, "min": 144, "max": 144}, "Max Records Seen Between Resets": {"sum": 4527.0, "count": 1, "min": 4527, "max": 4527}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 8.0, "count": 1, "min": 8, "max": 8}, "Number of Records Since Last Reset": {"sum": 4527.0, "count": 1, "min": 4527, "max": 4527}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [11/13/2021 21:31:07 INFO 140519838742336] #throughput_metric: host=algo-2, train throughput=2016.280319204855 records/second
# [11/13/2021 21:31:07 INFO 140519838742336]
# [11/13/2021 21:31:07 INFO 140519838742336] # Starting training for epoch 5
# [2021-11-13 21:31:08.251] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 14, "duration": 1213, "num_examples": 36, "num_bytes": 1059472}
# [11/13/2021 21:31:08 INFO 140380735153984] # Finished training epoch 5 on 4524 examples from 36 batches, each of size 128.
# [11/13/2021 21:31
# [11/13/2021 21:31:09 INFO 140380735153984] patience losses:[6.974809454547034, 6.880677150355445, 6.875515739123027, 6.873640656471252, 6.8691865934265985] min patience loss:6.8691865934265985 current loss:6.868226369222005 absolute loss difference:0.0009602242045936293
# [11/13/2021 21:31:09 INFO 140380735153984] Bad epoch: loss has not improved (enough). Bad count:1
# [11/13/2021 21:31:09 INFO 140380735153984] Timing: train: 1.21s, val: 0.00s, epoch: 1.21s
# [11/13/2021 21:31:09 INFO 140380735153984] #progress_metric: host=algo-1, completed 6.0 % of epochs
# #metrics {"StartTime": 1636839068.2568054, "EndTime": 1636839069.46501, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "epoch": 5, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 27144.0, "count": 1, "min": 27144, "max": 27144}, "Total Batches Seen": {"sum": 216.0, "count": 1, "min": 216, "max": 216}, "Max Records Seen Between Resets": {"sum": 4524.0, "count": 1, "min": 4524, "max": 4524}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Number of Records Since Last Reset": {"sum": 4524.0, "count": 1, "min": 4524, "max": 4524}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [11/13/2021 21:31:09 INFO 140380735153984] #throughput_metric: host=algo-1, train throughput=3743.9522290241352 records/second
# [11/13/2021 21:31:09 INFO 140380735153984]
# [11/13/2021 21:31:09 INFO 140380735153984] # Starting training for epoch 7
# [2021-11-13 21:31:09.704] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 17, "duration": 1259, "num_examples": 36, "num_bytes": 1038268}
# [11/13/2021 21:31:09 INFO 140519838742336] # Finished training epoch 6 on 4527 examples from 36 batches, each of size 128.
# [11/13/2021 21:31:09 INFO 140519838742336] Metrics for Training:
# [11/13/2021 21:31:09 INFO 140519838742336] Loss (name: value) total: 6.856396754582723
# [11/13/2021 21:31:09 INFO 140519838742336] Loss (name: value) kld: 0.01140763674953228
# [11/13/2021 21:31:09 INFO 140519838742336] Loss (name: value) recons: 6.844989087846544
# [11/13/2021 21:31:09 INFO 140519838742336] Loss (name: value) logppx: 6.856396754582723
# [11/13/2021 21:31:09 INFO 140519838742336] #quality_metric: host=algo-2, epoch=6, train total_loss <loss>=6.856396754582723
# [11/13/2021 21:31:09 INFO 140519838742336] patience losses:[6.957811527782017, 6.866222891542646, 6.86092867453893, 6.859765284591251, 6.855642444557613] min patience loss:6.855642444557613 current loss:6.856396754582723 absolute loss difference:0.0007543100251092838
# [11/13/2021 21:31:09 INFO 140519838742336] Bad epoch: loss has not improved (enough). Bad count:1
# [11/13/2021 21:31:09 INFO 140519838742336] Timing: train: 1.26s, val: 0.00s, epoch: 1.26s
# [11/13/2021 21:31:09 INFO 140519838742336] #progress_metric: host=algo-2, completed 6.0 % of epochs
# #metrics {"StartTime": 1636839068.443048, "EndTime": 1636839069.7065494, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training", "epoch": 5, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 27162.0, "count": 1, "min": 27162, "max": 27162}, "Total Batches Seen": {"sum": 216.0, "count": 1, "min": 216, "max": 216}, "Max Records Seen Between Resets": {"sum": 4527.0, "count": 1, "min": 4527, "max": 4527}, "Max Batches Seen Between Resets": {"sum": 36.0, "count": 1, "min": 36, "max": 36}, "Reset Count": {"sum": 12.0, "count": 1, "min": 12, "max": 12}, "Number of Records Since Last Reset": {"sum": 4527.0, "count": 1, "min": 4527, "max": 4527}, "Number of Batches Since Last Reset": {"sum": 36.0, "count": 1, "min": 36, "max": 36}}}
# [11/13/2021 21:31:09 INFO 140519838742336] #throughput_metric: host=algo-2, train throughput=3582.518022480814 records/second
# [11/13/2021 21:31:09 INFO 140519838742336]
# [11/13/2021 21:31:09 INFO 140519838742336] # Starting training for epoch 7
# [2021-11-13 21:31:10.630] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 20, "duration":
[tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 175, "num_examples": 18, "num_bytes": 524312}
# [11/13/2021 21:33:02 INFO 140380735153984] Finished scoring on 2176 examples from 17 batches, each of size 128.
# [11/13/2021 21:33:02 INFO 140380735153984] Metrics for Inference:
# [11/13/2021 21:33:02 INFO 140380735153984] Loss (name: value) total: 6.720432253444896
# [11/13/2021 21:33:02 INFO 140380735153984] Loss (name: value) kld: 0.17586701231844284
# [11/13/2021 21:33:02 INFO 140380735153984] Loss (name: value) recons: 6.544565284953398
# [11/13/2021 21:33:02 INFO 140380735153984] Loss (name: value) logppx: 6.720432253444896
# #metrics {"StartTime": 1636839182.3933318, "EndTime": 1636839182.570316, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training", "Meta": "test_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2263.0, "count": 1, "min": 2263, "max": 2263}, "Total Batches Seen": {"sum": 18.0, "count": 1, "min": 18, "max": 18}, "Max Records Seen Between Resets": {"sum": 2263.0, "count": 1, "min": 2263, "max": 2263}, "Max Batches Seen Between Resets": {"sum": 18.0, "count": 1, "min": 18, "max": 18}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 2263.0, "count": 1, "min": 2263, "max": 2263}, "Number of Batches Since Last Reset": {"sum": 18.0, "count": 1, "min": 18, "max": 18}}}
# [11/13/2021 21:33:02 INFO 140380735153984] #test_score (algo-1) : ('log_perplexity', 6.720432253444896)
# #metrics {"StartTime": 1636839059.8427215, "EndTime": 1636839182.571506, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 720.2315330505371, "count": 1, "min": 720.2315330505371, "max": 720.2315330505371}, "epochs": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "early_stop.time": {"sum": 219.99549865722656, "count": 76, "min": 0.1614093780517578, "max": 6.992340087890625}, "update.time": {"sum": 97008.05878639221, "count": 76, "min": 1138.6480331420898, "max": 1878.1847953796387}, "finalize.time": {"sum": 137.01605796813965, "count": 1, "min": 137.01605796813965, "max": 137.01605796813965}, "model.serialize.time": {"sum": 5.008220672607422, "count": 1, "min": 5.008220672607422, "max": 5.008220672607422}, "model.score.time": {"sum": 176.92065238952637, "count": 1, "min": 176.92065238952637, "max": 176.92065238952637}, "setuptime": {"sum": 1065.2375221252441, "count": 1, "min": 1065.2375221252441, "max": 1065.2375221252441}, "totaltime": {"sum": 123835.13760566711, "count": 1, "min": 123835.13760566711, "max": 123835.13760566711}}}
# [2021-11-13 21:33:02.583] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 168, "num_examples": 18, "num_bytes": 524312}
# [11/13/2021 21:33:02 INFO 140519838742336] Finished scoring on 2176 examples from 17 batches, each of size 128.
# [11/13/2021 21:33:02 INFO 140519838742336] Metrics for Inference:
# [11/13/2021 21:33:02 INFO 140519838742336] Loss (name: value) total: 6.728129863739014
# [11/13/2021 21:33:02 INFO 140519838742336] Loss (name: value) kld: 0.20807432953049154
# [11/13/2021 21:33:02 INFO 140519838742336] Loss (name: value) recons: 6.520055462332333
# [11/13/2021 21:33:02 INFO 140519838742336] Loss (name: value) logppx: 6.728129863739014
# #metrics {"StartTime": 1636839182.4146557, "EndTime": 1636839182.5841374, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training", "Meta": "test_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2263.0, "count": 1, "min": 2263, "max": 2263}, "Total Batches Seen": {"sum": 18.0, "count": 1, "min": 18, "max": 18}, "Max Records Seen Between Resets": {"sum": 2263.0, "count": 1, "min": 2263, "max": 2263}, "Max Batches Seen Between Resets": {"sum": 18.0, "count": 1, "min": 18, "max": 18}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 2263.0, "count": 1, "min": 2263, "max": 2263}, "Number of Batches Since Last Reset": {"sum": 18.0, "count": 1, "min": 18, "max": 18}}}
# [11/13/2021 21:33:02 INFO 140519838742336] #test_score (algo-2) : ('log_perplexity', 6.728129863739014)
# #metrics {"StartTime": 1636839060.012596, "EndTime": 1636839182.5852911, "Dimensions": {"Algorithm": "AWS/NTM", "Host": "algo-2", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 555.5155277252197, "count": 1, "min": 555.5155277252197, "max": 555.5155277252197}, "epochs": {"sum": 100.0, "count": 1, "min": 100, "max": 100}, "early_stop.time": {"sum": 292.88673400878906, "count": 100, "min": 0.1251697540283203, "max": 6.23774528503418}, "update.time": {"sum": 121601.18913650513, "count": 100, "min": 886.0135078430176, "max": 2244.1394329071045}, "finalize.time": {"sum": 155.90214729309082, "count": 1, "min": 155.90214729309082, "max": 155.90214729309082}, "model.serialize.time": {"sum": 5.699872970581055, "count": 1, "min": 5.699872970581055, "max": 5.699872970581055}, "model.score.time": {"sum": 169.42238807678223, "count": 1, "min": 169.42238807678223, "max": 169.42238807678223}, "setuptime": {"sum": 5580.58500289917, "count": 1, "min": 5580.58500289917, "max": 5580.58500289917}, "totaltime": {"sum": 128196.7122554779, "count": 1, "min": 128196.7122554779, "max": 128196.7122554779}}}
#
# 2021-11-13 21:33:33 Uploading - Uploading generated training model
# 2021-11-13 21:33:33 Completed - Training job completed
# ProfilerReport-1636838848: NoIssuesFound
# Training seconds: 338
# Billable seconds: 338

# %%
ntm_predictor = ntm.deploy(initial_instance_count=1, instance_type='ml.m4.xlarge')
# Out:
# ------!

# %%
from sagemaker.predictor import csv_serializer, json_deserializer
#ntm_predictor.content_type = 'text/csv'
ntm_predictor.serializer = csv_serializer
ntm_predictor.deserializer = json_deserializer

# %%
predictions = []
for item in np.array(vectors.todense()):
    np.shape(item)
    results = ntm_predictor.predict(item)
    predictions.append(np.array([prediction['topic_weights'] for prediction in results['predictions']]))
    
predictions = np.array([np.ndarray.flatten(x) for x in predictions])
topicvec = train_labels[newidx]
topicnames = [categories[x] for x in topicvec]
# Out:
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# ...
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The csv_serializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# The json_deserializer has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-3a72cd3cb6da> in <module>
#       6
#       7 predictions = np.array([np.ndarray.flatten(x) for x in predictions])
# ----> 8 topicvec = train_labels[newidx]
#       9 topicnames = [categories[x] for x in topicvec]
#
# NameError: name 'train_labels' is not defined

# %%
pip install --upgrade sagemaker
# Out:
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.66.0)
# Collecting sagemaker
#   Downloading sagemaker-2.69.0.tar.gz (452 kB)
#      |████████████████████████████████| 452 kB 4.8 MB/s
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: attrs in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (21.2.0)
# Requirement already satisfied: boto3>=1.16.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.19.3)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.19.5)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.19.0)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: smdebug_rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (4.8.1)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (21.2)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.1.5)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.8)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.5.0)
# Requirement already satisfied: botocore<1.23.0,>=1.22.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (1.22.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.10.0)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.10.0.2)
# Collecting pyparsing<3,>=2.0.2
#   Downloading pyparsing-2.4.7-py2.py3-none-any.whl (67 kB)
#      |████████████████████████████████| 67 kB 5.3 MB/s
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from protobuf3-to-dict>=0.1.5->sagemaker) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->sagemaker) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->sagemaker) (2021.3)
# Requirement already satisfied: multiprocess>=0.70.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.70.12.2)
# Requirement already satisfied: pox>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.3.0)
# Requirement already satisfied: ppft>=1.6.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (1.6.6.4)
# Requirement already satisfied: dill>=0.3.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.3.4)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.23.0,>=1.22.3->boto3>=1.16.32->sagemaker) (1.26.7)
# Building wheels for collected packages: sagemaker
#   Building wheel for sagemaker (setup.py) ... done
#   Created wheel for sagemaker: filename=sagemaker-2.69.0-py2.py3-none-any.whl size=625707 sha256=a7e056454d59fc183f9cff945bdc7fe88219ab29d0a679e22458797bfe01fc4f
#   Stored in directory: /home/ec2-user/.cache/pip/wheels/f4/2c/36/3ab4164cdc3413eb82504df7915934940baa5aa7fac923dc0f
# Successfully built sagemaker
# Installing collected packages: pyparsing, sagemaker
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.0.1
#     Uninstalling pyparsing-3.0.1:
#       Successfully uninstalled pyparsing-3.0.1
#   Attempting uninstall: sagemaker
#     Found existing installation: sagemaker 2.66.0
#     Uninstalling sagemaker-2.66.0:
#       Successfully uninstalled sagemaker-2.66.0
# Successfully installed pyparsing-2.4.7 sagemaker-2.69.0
# Note: you may need to restart the kernel to use updated packages.

# %%
###trying option B

np.savetxt('trainvectors.csv',
           vectors.todense(),
           delimiter=',',
           fmt='%i')
batch_prefix = '20newsgroups/batch'

train_s3 = sess.upload_data('trainvectors.csv', 
                            bucket=bucket, 
                            key_prefix='{}/train'.format(batch_prefix))
print(train_s3)
batch_output_path = 's3://{}/{}/test'.format(bucket, batch_prefix)

ntm_transformer = ntm.transformer(instance_count=1,
                                  instance_type ='ml.m4.xlarge',
                                  output_path=batch_output_path
                                 )
ntm_transformer.transform(train_s3, content_type='text/csv', split_type='Line')
ntm_transformer.wait()
# Out:
# s3://sagemaker-crsmids/20newsgroups/batch/train/trainvectors.csv
# .................................Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# /opt/amazon/lib/python3.7/site-packages/jsonref.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping, MutableMapping, Sequence
# Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# /opt/amazon/lib/python3.7/site-packages/jsonref.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping, MutableMapping, Sequence
# /opt/amazon/lib/python3.7/site-packages/google/protobuf/internal/api_implementation.py:151: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from google.protobuf.pyext import _message
# [11/13/2021 22:02:43 INFO 140095194376000] loaded entry point class algorithm.serve.server_config:config_api
# [11/13/2021 22:02:43 INFO 140095194376000] loading entry points
# /opt/amazon/lib/python3.7/site-packages/ai_algorithms_sdk/serve.py:220: DeprecationWarning: entrypoint algorithm.request_iterators is deprecated in favor of algorithm.io.data_handlers.serve
#   "in favor of algorithm.io.data_handlers.serve", DeprecationWarning)
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator application/json
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator application/jsonlines
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator application/x-recordio-protobuf
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator text/csv
# [11/13/2021 22:02:43 INFO 140095194376000] loaded response encoder application/json
# [11/13/2021 22:02:43 INFO 140095194376000] loaded response encoder application/jsonlines
# [11/13/2021 22:02:43 INFO 140095194376000] loaded response encoder application/x-recordio-protobuf
# /opt/amazon/lib/python3.7/site-packages/google/protobuf/internal/api_implementation.py:151: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from google.protobuf.pyext import _message
# [11/13/2021 22:02:43 INFO 140095194376000] loaded entry point class algorithm.serve.server_config:config_api
# [11/13/2021 22:02:43 INFO 140095194376000] loading entry points
# /opt/amazon/lib/python3.7/site-packages/ai_algorithms_sdk/serve.py:220: DeprecationWarning: entrypoint algorithm.request_iterators is deprecated in favor of algorithm.io.data_handlers.serve
#   "in favor of algorithm.io.data_handlers.serve", DeprecationWarning)
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator application/json
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator application/jsonlines
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator application/x-recordio-protobuf
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator text/csv
# [11/13/2021 22:02:43 INFO 140095194376000] loaded response encoder application/json
# [11/13/2021 22:02:43 INFO 140095194376000] loaded response encoder application/jsonlines
# [11/13/2021 22:02:43 INFO 140095194376000] loaded response encoder application/x-recordio-protobuf
# [11/13/2021 22:02:43 INFO 140095194376000] loaded entry point class algorithm:model
# [11/13/2021 22:02:43 INFO 140095194376000] Number of server workers: 1
# [2021-11-13 22:02:43 +0000] [1] [INFO] Starting gunicorn 20.0.4
# [2021-11-13 22:02:43 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2021-11-13 22:02:43 +0000] [1] [INFO] Using worker: sync
# [2021-11-13 22:02:43 +0000] [31] [INFO] Booting worker with pid: 31
# [11/13/2021 22:02:43 INFO 140095194376000] loading model...
# [11/13/2021 22:02:43 INFO 140095194376000] Deserialized model from /opt/ml/model
# [11/13/2021 22:02:43 WARNING 140095194376000] Requesting context without setting the requested num of gpus. Using 'auto'
# [11/13/2021 22:02:43 INFO 140095194376000] nvidia-smi: took 0.028 seconds to run.
# [11/13/2021 22:02:43 INFO 140095194376000] nvidia-smi identified 0 GPUs.
# [11/13/2021 22:02:43 INFO 140095194376000] Number of GPUs being used: 0
# [11/13/2021 22:02:43 WARNING 140095194376000] Requesting context without setting the requested num of gpus. Using 'auto'
# [11/13/2021 22:02:43 INFO 140095194376000] Number of GPUs being used: 0
# [11/13/2021 22:02:43 INFO 140095194376000] ...model loaded.
# [11/13/2021 22:02:43 INFO 140095194376000] loaded entry point class algorithm:model
# [11/13/2021 22:02:43 INFO 140095194376000] Number of server workers: 1
# [2021-11-13 22:02:43 +0000] [1] [INFO] Starting gunicorn 20.0.4
# [2021-11-13 22:02:43 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2021-11-13 22:02:43 +0000] [1] [INFO] Using worker: sync
# [2021-11-13 22:02:43 +0000] [31] [INFO] Booting worker with pid: 31
# [11/13/2021 22:02:43 INFO 140095194376000] loading model...
# [11/13/2021 22:02:43 INFO 140095194376000] Deserialized model from /opt/ml/model
# [11/13/2021 22:02:43 WARNING 140095194376000] Requesting context without setting the requested num of gpus. Using 'auto'
# [11/13/2021 22:02:43 INFO 140095194376000] nvidia-smi: took 0.028 seconds to run.
# [11/13/2021 22:02:43 INFO 140095194376000] nvidia-smi identified 0 GPUs.
# [11/13/2021 22:02:43 INFO 140095194376000] Number of GPUs being used: 0
# [11/13/2021 22:02:43 WARNING 140095194376000] Requesting context without setting the requested num of gpus. Using 'auto'
# [11/13/2021 22:02:43 INFO 140095194376000] Number of GPUs being used: 0
# [11/13/2021 22:02:43 INFO 140095194376000] ...model loaded.
# #metrics {"StartTime": 1636840963.6389592, "EndTime": 1636840966.0948367, "Dimensions": {"Algorithm": "NVDMModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"execution_parameters.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1636840963.6389592, "EndTime": 1636840966.0948367, "Dimensions": {"Algorithm": "NVDMModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"execution_parameters.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1636840966.0949554, "EndTime": 1636840967.9889917, "Dimensions": {"Algorithm": "NVDMModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"model.evaluate.time": {"sum": 5.922794342041016, "count": 1, "min": 5.922794342041016, "max": 5.922794342041016}, "json.encoder.time": {"sum": 40.389299392700195, "count": 1, "min": 40.389299392700195, "max": 40.389299392700195}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1636
}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1636840970.8037894, "EndTime": 1636840971.3880346, "Dimensions": {"Algorithm": "NVDMModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"model.evaluate.time": {"sum": 0.6716251373291016, "count": 1, "min": 0.6716251373291016, "max": 0.6716251373291016}, "json.encoder.time": {"sum": 29.471635818481445, "count": 1, "min": 29.471635818481445, "max": 29.471635818481445}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
# #metrics {"StartTime": 1636840971.3881574, "EndTime": 1636840971.5051212, "Dimensions": {"Algorithm": "NVDMModel", "Host": "UNKNOWN", "Operation": "scoring"}, "Metrics": {"model.evaluate.time": {"sum": 2.8121471405029297, "count": 1, "min": 2.8121471405029297, "max": 2.8121471405029297}, "json.encoder.time": {"sum": 4.155635833740234, "count": 1, "min": 4.155635833740234, "max": 4.155635833740234}, "invocations.count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}}}
#
# Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# /opt/amazon/lib/python3.7/site-packages/jsonref.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping, MutableMapping, Sequence
# Docker entrypoint called with argument(s): serve
# Running default environment configuration script
# /opt/amazon/lib/python3.7/site-packages/jsonref.py:8: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from collections import Mapping, MutableMapping, Sequence
# /opt/amazon/lib/python3.7/site-packages/google/protobuf/internal/api_implementation.py:151: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from google.protobuf.pyext import _message
# [11/13/2021 22:02:43 INFO 140095194376000] loaded entry point class algorithm.serve.server_config:config_api
# [11/13/2021 22:02:43 INFO 140095194376000] loading entry points
# /opt/amazon/lib/python3.7/site-packages/ai_algorithms_sdk/serve.py:220: DeprecationWarning: entrypoint algorithm.request_iterators is deprecated in favor of algorithm.io.data_handlers.serve
#   "in favor of algorithm.io.data_handlers.serve", DeprecationWarning)
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator application/json
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator application/jsonlines
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator application/x-recordio-protobuf
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator text/csv
# [11/13/2021 22:02:43 INFO 140095194376000] loaded response encoder application/json
# [11/13/2021 22:02:43 INFO 140095194376000] loaded response encoder application/jsonlines
# [11/13/2021 22:02:43 INFO 140095194376000] loaded response encoder application/x-recordio-protobuf
# /opt/amazon/lib/python3.7/site-packages/google/protobuf/internal/api_implementation.py:151: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3,and in 3.9 it will stop working
#   from google.protobuf.pyext import _message
# [11/13/2021 22:02:43 INFO 140095194376000] loaded entry point class algorithm.serve.server_config:config_api
# [11/13/2021 22:02:43 INFO 140095194376000] loading entry points
# /opt/amazon/lib/python3.7/site-packages/ai_algorithms_sdk/serve.py:220: DeprecationWarning: entrypoint algorithm.request_iterators is deprecated in favor of algorithm.io.data_handlers.serve
#   "in favor of algorithm.io.data_handlers.serve", DeprecationWarning)
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator application/json
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator application/jsonlines
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator application/x-recordio-protobuf
# [11/13/2021 22:02:43 INFO 140095194376000] loaded request iterator text/csv
# [11/13/2021 22:02:43 INFO 140095194376000] loaded response encoder application/json
# [11/13/2021 22:02:43 INFO 140095194376000] loaded response encoder application/jsonlines
# [11/13/2021 22:02:43 INFO 140095194376000] loaded response encoder application/x-recordio-protobuf
# [11/13/2021 22:02:43 INFO 140095194376000] loaded entry point class algorithm:model
# [11/13/2021 22:02:43 INFO 140095194376000] Number of server workers: 1
# [2021-11-13 22:02:43 +0000] [1] [INFO] Starting gunicorn 20.0.4
# [2021-11-13 22:02:43 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2021-11-13 22:02:43 +0000] [1] [INFO] Using worker: sync
# [2021-11-13 22:02:43 +0000] [31] [INFO] Booting worker with pid: 31
# [11/13/2021 22:02:43 INFO 140095194376000] loading model...
# [11/13/2021 22:02:43 INFO 140095194376000] Deserialized model from /opt/ml/model
# [11/13/2021 22:02:43 WARNING 140095194376000] Requesting context without setting the requested num of gpus. Using 'auto'
# [11/13/2021 22:02:43 INFO 140095194376000] nvidia-smi: took 0.028 seconds to run.
# [11/13/2021 22:02:43 INFO 140095194376000] nvidia-smi identified 0 GPUs.
# [11/13/2021 22:02:43 INFO 140095194376000] Number of GPUs being used: 0
# [11/13/2021 22:02:43 WARNING 140095194376000] Requesting context without setting the requested num of gpus. Using 'auto'
# [11/13/2021 22:02:43 INFO 140095194376000] Number of GPUs being used: 0
# [11/13/2021 22:02:43 INFO 140095194376000] ...model loaded.
# [11/13/2021 22:02:43 INFO 140095194376000] loaded entry point class algorithm:model
# [11/13/2021 22:02:43 INFO 140095194376000] Number of server workers: 1
# [2021-11-13 22:02:43 +0000] [1] [INFO] Starting gunicorn 20.0.4
# [2021-11-13 22:02:43 +0000] [1] [INFO] Listening at: http://0.0.0.0:8080 (1)
# [2021-11-13 22:02:43 +0000] [1] [INFO] Using worker: sync
# [2021-11-13 22:02:43 +0000] [31] [INFO] Booting worker with pid: 31
# [11/13/2021 22:02:43 INFO 140095194376000] loading model...
# [11/13/2021 22:02:43 INFO 140095194376000] Deserialized model from /opt/ml/model
# [11/13/2021 22:02:43 WARNING 140095194376000] Requesting context without setting the requested num of gpus. Using 'auto'
# [11/13/2021 22:02:43 INFO 140095194376000] nvidia-smi: took 0.028 seconds to run.
# [11/13/2021 22:02:43 INFO 140095194376000] nvidia-smi identified 0 GPUs.
# [11/13/2021 22:02:43 INFO 140095194376000] Number of GPUs being used: 0
# [11/13/2021 22:02:43
# {"topic_weights":[0.0301307794,0.0266190395,0.0535682067,0.0340667181,0.0362115465,0.0327198207,0.0284178257,0.0359561741,0.0633199587,0.0366961583,0.0300415792,0.0324362293,0.0295743104,0.0224095024,0.0287606269,0.0382551178,0.0236524362,0.0310212728,0.0335664488,0.0334255137,0.031131709,0.032695014,0.0320614129,0.0331331417,0.0335106924,0.0271573421,0.0341339186,0.0200132336,0.0369261056,0.0383881889]}
# {"topic_weights":[0.0322778784,0.0428907871,0.0237615351,0.0316757299,0.0300153121,0.0284986347,0.0357175544,0.0308171324,0

# %%
conda update --all
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - conda-forge/noarch::seaborn-base==0.11.1=pyhd8ed1ab_1
#   - conda-forge/noarch::nbclassic==0.2.6=pyhd8ed1ab_0
#   - conda-forge/noarch::typing-extensions==3.7.4.3=0
#   - conda-forge/linux-64::pluggy==0.13.1=py36h5fab9bb_4
#   - conda-forge/linux-64::blaze==0.11.3=py36_0
#   - conda-forge/linux-64::matplotlib==3.3.4=py36h5fab9bb_0
#   - defaults/linux-64::_anaconda_depends==5.1.0=py36_2
#   - conda-forge/noarch::python-language-server==0.36.2=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab_server==2.3.0=pyhd8ed1ab_0
#   - conda-forge/noarch::pyls-black==0.4.6=pyh9f0ad1d_0
#   - conda-forge/linux-64::scikit-image==0.16.2=py36hb3f55d8_0
#   - conda-forge/noarch::path.py==12.5.0=0
#   - conda-forge/noarch::qdarkstyle==2.8.1=pyhd8ed1ab_2
#   - conda-forge/noarch::ipywidgets==7.6.3=pyhd3deb0d_0
#   - conda-forge/noarch::black==20.8b1=py_1
#   - conda-forge/linux-64::anyio==2.1.0=py36h5fab9bb_0
#   - conda-forge/linux-64::jupyter_server==1.4.1=py36h5fab9bb_0
#   - conda-forge/noarch::nbclient==0.5.2=pyhd8ed1ab_0
#   - conda-forge/linux-64::widgetsnbextension==3.5.1=py36h5fab9bb_4
#   - conda-forge/linux-64::bokeh==2.2.3=py36h5fab9bb_0
#   - conda-forge/linux-64::keyring==22.0.1=py36h5fab9bb_0
#   - conda-forge/linux-64::nbconvert==6.0.7=py36h5fab9bb_3
#   - conda-forge/noarch::numpydoc==1.1.0=py_1
#   - conda-forge/linux-64::spyder==4.2.0=py36h5fab9bb_0
#   - conda-forge/noarch::flake8==3.8.4=py_0
#   - conda-forge/noarch::pyls-spyder==0.3.2=pyhd8ed1ab_0
#   - conda-forge/noarch::nbformat==5.1.2=pyhd8ed1ab_1
#   - conda-forge/noarch::aioitertools==0.7.1=pyhd8ed1ab_0
#   - conda-forge/noarch::jupyterlab_launcher==0.13.1=py_2
#   - conda-forge/noarch::odo==0.5.1=py_1
#   - conda-forge/noarch::imageio==2.9.0=py_0
#   - conda-forge/noarch::helpdev==0.7.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::path==15.1.2=py36h5fab9bb_0
#   - conda-forge/noarch::jsonschema==3.2.0=py_2
#   - conda-forge/linux-64::yarl==1.6.3=py36h8f6f2f9_1
#   - conda-forge/noarch::sphinx==3.5.1=pyhd8ed1ab_0
#   - conda-forge/noarch::seaborn==0.11.1=hd8ed1ab_1
#   - conda-forge/linux-64::jupyter==1.0.0=py36h5fab9bb_6
#   - conda-forge/linux-64::nb_conda==2.2.1=py36h5fab9bb_4
#   - conda-forge/noarch::dask==2021.2.0=pyhd8ed1ab_0
#   - conda-forge/linux-64::matplotlib-base==3.3.4=py36hd391965_0
#   - conda-forge/noarch::anaconda-client==1.7.2=py_0
#   - conda-forge/noarch::importlib_metadata==3.7.0=hd8ed1ab_0
#   - conda-forge/noarch::anaconda-project==0.9.1=pyhd8ed1ab_0
#   - conda-forge/linux-64::pytest==6.2.2=py36h5fab9bb_0
#   - conda-forge/linux-64::importlib-metadata==3.7.0=py36h5fab9bb|
# \
# Warning: 4 possible package resolutions (only showing differing packages):
#   - conda-forge/linux-64::libprotobuf-3.19.1-h780b84a_0, conda-forge/linux-64::protobuf-3.4.1-py36_0, conda-forge/noarch::packaging-21.2-pyhd8ed1ab_1, conda-forge/noarch::pyparsing-2.4.7-pyhd8ed1ab_1
#   - conda-forge/linux-64::libprotobuf-3.15.8-h780b84a_1, conda-forge/linux-64::protobuf-3.15.8-py36hc4f0c31_0, conda-forge/noarch::packaging-21.2-pyhd8ed1ab_1, conda-forge/noarch::pyparsing-2.4.7-pyhd8ed1ab_1
#   - conda-forge/linux-64::libprotobuf-3.15.8-h780b84a_1, conda-forge/linux-64::protobuf-3.15.8-py36hc4f0c31_0, conda-forge/noarch::packaging-21.0-pyhd8ed1ab_0, conda-forge/noarch::pyparsing-3.0.6-pyhd8ed1ab_0
#   - conda-forge/linux-64::libprotobuf-3.19.1-h780b84a_0, conda-forge/linux-64::protobuf-3.4.1-py36_0, conda-forge/noarch::packaging-21.0-pyhd8ed1ab_0, conda-forge/noarch::pyparsing-3.0.6-pyhd8ed1abdone
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.4
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /home/ec2-user/anaconda3/envs/python3
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |           1_llvm           5 KB  conda-forge
#     argon2-cffi-21.1.0         |   py36h8f6f2f9_0          46 KB  conda-forge
#     async-timeout-4.0.0        |     pyhd8ed1ab_0           9 KB  conda-forge
#     beautifulsoup4-4.10.0      |     pyha770c72_0          77 KB  conda-forge
#     bitarray-2.3.4             |   py36h8f6f2f9_1         139 KB  conda-forge
#     bottleneck-1.3.2           |   py36he33b4a0_4         129 KB  conda-forge
#     c-ares-1.18.1              |       h7f98852_0         113 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     charset-normalizer-2.0.0   |     pyhd8ed1ab_0          32 KB  conda-forge
#     cloudpickle-2.0.0          |     pyhd8ed1ab_0          24 KB  conda-forge
#     contextlib2-21.6.0         |     pyhd8ed1ab_0          16 KB  conda-forge
#     curl-7.80.0                |       h2574ce0_0         153 KB  conda-forge
#     cycler-0.11.0              |     pyhd8ed1ab_0          10 KB  conda-forge
#     cython-0.29.24             |   py36hc4f0c31_0         2.2 MB  conda-forge
#     dataclasses-0.8            |     pyh787bdff_2          22 KB  conda-forge
#     deprecation-2.1.0          |     pyh9f0ad1d_0          14 KB  conda-forge
#     filelock-3.3.2             |     pyhd8ed1ab_0          12 KB  conda-forge
#     flask-2.0.2                |     pyhd8ed1ab_0          70 KB  conda-forge
#     flask-cors-3.0.10          |     pyhd8ed1ab_0          15 KB  conda-forge
#     fsspec-2021.11.0           |     pyhd8ed1ab_0          91 KB  conda-forge
#     icu-68.2                   |       h9c3ff4c_0        13.1 MB  conda-forge
#     idna_ssl-1.1.0             |  pyhd8ed1ab_1002           7 KB  conda-forge
#     imagesize-1.3.0            |     pyhd8ed1ab_0           9 KB  conda-forge
#     immutables-0.16            |   py36h8f6f2f9_0          65 KB  conda-forge
#     intel-openmp-2021.4.0      |    h06a4308_3561         4.2 MB
#     ipyparallel-8.0.0          |     pyhd8ed1ab_0         243 KB  conda-forge
#     isort-5.10.1               |     pyhd8ed1ab_0          79 KB  conda-forge
#     jeepney-0.7.1              |     pyhd8ed1ab_0          38 KB  conda-forge
#     jinja2-3.0.3               |     pyhd8ed1ab_0          99 KB  conda-forge
#     joblib-1.1.0               |     pyhd8ed1ab_0         210 KB  conda-forge
#     jupyter-packaging-0.11.0   |     pyhd8ed1ab_0          17 KB  conda-forge
#     jupyterlab-3.2.3           |     pyhd8ed1ab_0         6.0 MB  conda-forge
#     krb5-1.19.2                |       hcc1bbae_3         1.4 MB  conda-forge
#     libcurl-7.80.0             |       h2574ce0_0         337 KB  conda-forge
#     libnghttp2-1.43.0          |       h812cca2_1         790 KB  conda-forge
#     libpq-13.3                 |       hd57d9b9_3         2.7 MB  conda-forge
#     libprotobuf-3.19.1         |       h780b84a_0         2.6 MB  conda-forge
#     libspatialindex-1.9.3      |       h9c3ff4c_4         4.6 MB  conda-forge
#     libssh2-1.10.0             |       ha56f1ee_2         233 KB  conda-forge
#     libxcb-1.13                |    h7f98852_1004         391 KB  conda-forge
#     llvm-openmp-12.0.1         |       h4bd325d_1         2.8 MB  conda-forge
#     lxml-3.8.0                 |           py36_0         3.8 MB  conda-forge
#     mkl-2020.4                 |     h726a3e6_304       215.6 MB  conda-forge
#     more-itertools-8.11.0      |     pyhd8ed1ab_0          47 KB  conda-forge
#     mpc-1.2.1                  |       h9f54685_0         106 KB  conda-forge
#     mpfr-4.1.0                 |       h9202a9a_1         2.6 MB  conda-forge
#     mysql-common-8.0.27        |       ha770c72_1         1.8 MB  conda-forge
#     mysql-libs-8.0.27          |       hfa10184_1         1.9 MB  conda-forge
#     networkx-2.6.3             |     pyhd8ed1ab_1         1.5 MB  conda-forge
#     notebook-6.3.0             |   py36h5fab9bb_0         6.3 MB  conda-forge
#     nspr-4.32                  |       h9c3ff4c_1         233 KB  conda-forge
#     nss-3.72                   |       hb5efdd6_0         2.1 MB  conda-forge
#     numexpr-2.7.3              |   py36h0cdc3f0_0         200 KB  conda-forge
#     openpyxl-3.0.9             |     pyhd8ed1ab_0         153 KB  conda-forge
#     packaging-21.2             |     pyhd8ed1ab_1          35 KB  conda-forge
#     pandoc-2.16.1              |       h7f98852_0        12.6 MB  conda-forge
#     patchelf-0.13              |       h58526e2_0          84 KB  conda-forge
#     pathlib2-2.3.6             |   py36h5fab9bb_0          35 KB  conda-forge
#     pathspec-0.9.0             |     pyhd8ed1ab_0          31 KB  conda-forge
#     patsy-0.5.2                |     pyhd8ed1ab_0         188 KB  conda-forge
#     pillow-7.2.0               |   py36h8328e55_2         679 KB  conda-forge
#     pkginfo-1.7.1              |     pyhd8ed1ab_0          22 KB  conda-forge
#     prometheus_client-0.12.0   |     pyhd8ed1ab_0          47 KB  conda-forge
#     prompt-toolkit-3.0.22      |     pyha770c72_0         249 KB  conda-forge
#     prompt_toolkit-3.0.22      |       hd8ed1ab_0           5 KB  conda-forge
#     protobuf-3.4.1             |           py36_0         5.6 MB  conda-forge
#     py-1.11.0                  |     pyh6c4a22f_0          74 KB  conda-forge
#     pycparser-2.21             |     pyhd8ed1ab_0         100 KB  conda-forge
#     pycurl-7.44.1              |   py36h66a4f8d_0          70 KB  conda-forge
#     pylint-2.7.2               |   py36h5fab9bb_0         466 KB  conda-forge
#     pyodbc-4.0.32              |   py36hc4f0c31_0          75 KB  conda-forge
#     pyparsing-2.4.7            |     pyhd8ed1ab_1          60 KB  conda-forge
#     pyyaml-5.4.1               |   py36h8f6f2f9_1         194 KB  conda-forge
#     qtawesome-1.1.0            |     pyhd8ed1ab_0         2.0 MB  conda-forge
#     qtconsole-5.2.0            |     pyhd8ed1ab_0          90 KB  conda-forge
#     requests-2.26.0            |     pyhd8ed1ab_0          52 KB  conda-forge
#     rope-0.21.1                |     pyhd8ed1ab_0         122 KB  conda-forge
#     scikit-learn-0.24.2        |   py36hc89565f_1         7.5 MB  conda-forge
#     scipy-1.5.3                |   py36h81d768a_1        19.1 MB  conda-forge
#     soupsieve-2.3              |     pyhd8ed1ab_0          33 KB  conda-forge
#     threadpoolctl-3.0.0        |     pyh8a188c0_0          17 KB  conda-forge
#     tomlkit-0.7.2              |     pyha770c72_1          30 KB  conda-forge
#     toolz-0.11.2               |     pyhd8ed1ab_0          48 KB  conda-forge
#     tqdm-4.62.3                |     pyhd8ed1ab_0          80 KB  conda-forge
#     typing-3.10.0.0            |     pyhd8ed1ab_0           7 KB  conda-forge
#     ujson-4.2.0                |   py36hc4f0c31_0          48 KB  conda-forge
#     watchdog-2.1.6             |   py36h5fab9bb_0          94 KB  conda-forge
#     wurlitzer-3.0.2            |   py36h5fab9bb_0          15 KB  conda-forge
#     xlsxwriter-3.0.2           |     pyhd8ed1ab_0         108 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       329.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   astroid            conda-forge/linux-64::astroid-2.5.8-py36h5fab9bb_0
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   charset-normalizer conda-forge/noarch::charset-normalizer-2.0.0-pyhd8ed1ab_0
#   colorama           conda-forge/noarch::colorama-0.4.4-pyh9f0ad1d_0
#   dataclasses        conda-forge/noarch::dataclasses-0.8-pyh787bdff_2
#   deprecation        conda-forge/noarch::deprecation-2.1.0-pyh9f0ad1d_0
#   docutils           conda-forge/linux-64::docutils-0.16-py36h5fab9bb_3
#   flask-cors         conda-forge/noarch::flask-cors-3.0.10-pyhd8ed1ab_0
#   fsspec             conda-forge/noarch::fsspec-2021.11.0-pyhd8ed1ab_0
#   jupyter_console    conda-forge/noarch::jupyter_console-6.4.0-pyhd8ed1ab_0
#   jupyterlab         conda-forge/noarch::jupyterlab-3.2.3-pyhd8ed1ab_0
#   lerc               conda-forge/linux-64::lerc-3.0-h9c3ff4c_0
#   libdeflate         conda-forge/linux-64::libdeflate-1.8-h7f98852_0
#   libzlib            conda-forge/linux-64::libzlib-1.2.11-h36c2ea0_1013
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-12.0.1-h4bd325d_1
#   lxml               conda-forge/linux-64::lxml-3.8.0-py36_0
#   notebook           conda-forge/linux-64::notebook-6.3.0-py36h5fab9bb_0
#   pillow             conda-forge/linux-64::pillow-7.2.0-py36h8328e55_2
#   pip                conda-forge/noarch::pip-21.3.1-pyhd8ed1ab_0
#   pylint             conda-forge/linux-64::pylint-2.7.2-py36h5fab9bb_0
#   requests           conda-forge/noarch::requests-2.26.0-pyhd8ed1ab_0
#   tomlkit            conda-forge/noarch::tomlkit-0.7.2-pyha770c72_1
#   tqdm               conda-forge/noarch::tqdm-4.62.3-pyhd8ed1ab_0
#   typing_extensions  conda-forge/noarch::typing_extensions-3.10.0.2-pyha770c72_0
#   urllib3            conda-forge/noarch::urllib3-1.26.7-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   argon2-cffi                         20.1.0-py36h8f6f2f9_2 --> 21.1.0-py36h8f6f2f9_0
#   async-timeout                               3.0.1-py_1000 --> 4.0.0-pyhd8ed1ab_0
#   attrs                                 20.3.0-pyhd3deb0d_0 --> 21.2.0-pyhd8ed1ab_0
#   babel                                  2.9.0-pyhd3deb0d_0 --> 2.9.1-pyh44b312d_0
#   backports.functoo~                             1.6.1-py_0 --> 1.6.4-pyhd8ed1ab_0
#   beautifulsoup4                         4.9.3-pyhb0f4dca_0 --> 4.10.0-pyha770c72_0
#   bitarray                             1.6.3-py36h8f6f2f9_0 --> 2.3.4-py36h8f6f2f9_1
#   bleach                                 3.3.0-pyh44b312d_0 --> 4.1.0-pyhd8ed1ab_0
#   bottleneck                           1.3.2-py36h92226af_3 --> 1.3.2-py36he33b4a0_4
#   c-ares                                  1.17.1-h36c2ea0_0 --> 1.18.1-h7f98852_0
#   ca-certificates                      2021.5.30-ha878542_0 --> 2021.10.8-ha878542_0
#   cached-property                                1.5.1-py_0 --> 1.5.2-hd8ed1ab_1
#   chardet                           3.0.4-py36h9880bd3_1008 --> 4.0.0-py36h5fab9bb_1
#   cloudpickle                                    1.6.0-py_0 --> 2.0.0-pyhd8ed1ab_0
#   contextlib2                              0.6.0.post1-py_0 --> 21.6.0-pyhd8ed1ab_0
#   cryptography                         3.4.4-py36hc39840e_0 --> 35.0.0-py36hb60f036_0
#   curl                                    7.71.1-he644dc0_8 --> 7.80.0-h2574ce0_0
#   cycler                                        0.10.0-py_2 --> 0.11.0-pyhd8ed1ab_0
#   cython                             0.29.22-py36hc4f0c31_0 --> 0.29.24-py36hc4f0c31_0
#   decorator                                      4.4.2-py_0 --> 5.1.0-pyhd8ed1ab_0
#   defusedxml                                     0.6.0-py_0 --> 0.7.1-pyhd8ed1ab_0
#   filelock                              3.0.12-pyh9f0ad1d_0 --> 3.3.2-pyhd8ed1ab_0
#   flask                                  1.1.2-pyh9f0ad1d_0 --> 2.0.2-pyhd8ed1ab_0
#   font-ttf-inconsol~                       2.001-hab24e00_0 --> 3.000-h77eed37_0
#   font-ttf-source-c~                       2.030-hab24e00_0 --> 2.038-h77eed37_0
#   fontconfig                           2.13.1-hba837de_1004 --> 2.13.1-hba837de_1005
#   icu                                       68.1-h58526e2_0 --> 68.2-h9c3ff4c_0
#   idna_ssl           conda-forge/linux-64::idna_ssl-1.1.0-~ --> conda-forge/noarch::idna_ssl-1.1.0-pyhd8ed1ab_1002
#   imagesize                                      1.2.0-py_0 --> 1.3.0-pyhd8ed1ab_0
#   immutables                            0.15-py36h8f6f2f9_0 --> 0.16-py36h8f6f2f9_0
#   intel-openmp                                   2020.2-254 --> 2021.4.0-h06a4308_3561
#   ipykernel                            5.5.0-py36he448a4c_1 --> 5.5.5-py36hcb3619a_0
#   ipyparallel        conda-forge/linux-64::ipyparallel-6.3~ --> conda-forge/noarch::ipyparallel-8.0.0-pyhd8ed1ab_0
#   isort                                  5.7.0-pyhd8ed1ab_0 --> 5.10.1-pyhd8ed1ab_0
#   itsdangerous                                   1.1.0-py_0 --> 2.0.1-pyhd8ed1ab_0
#   jbig                                    2.1-h516909a_2002 --> 2.1-h7f98852_2003
#   jeepney                                0.6.0-pyhd8ed1ab_0 --> 0.7.1-pyhd8ed1ab_0
#   jinja2                                2.11.3-pyh44b312d_0 --> 3.0.3-pyhd8ed1ab_0
#   joblib                                 1.0.1-pyhd8ed1ab_0 --> 1.1.0-pyhd8ed1ab_0
#   jupyter-packaging                     0.7.12-pyhd8ed1ab_0 --> 0.11.0-pyhd8ed1ab_0
#   jupyter_client                        6.1.11-pyhd8ed1ab_1 --> 7.0.6-pyhd8ed1ab_0
#   jupyterlab_widgets                     1.0.0-pyhd8ed1ab_1 --> 1.0.2-pyhd8ed1ab_0
#   krb5                                    1.17.2-h926e7f8_0 --> 1.19.2-hcc1bbae_3
#   lazy-object-proxy                    1.5.2-py36h8f6f2f9_1 --> 1.6.0-py36h8f6f2f9_0
#   ld_impl_linux-64                        2.35.1-hea4e1c9_2 --> 2.36.1-hea4e1c9_2
#   libblas                                  3.9.0-8_openblas --> 3.9.0-12_linux64_openblas
#   libcblas                                 3.9.0-8_openblas --> 3.9.0-12_linux64_openblas
#   libclang                        11.0.1-default_ha53f305_1 --> 11.1.0-default_ha53f305_1
#   libcurl                                 7.71.1-hcdd3856_8 --> 7.80.0-h2574ce0_0
#   libevent                                2.1.10-hcdb4288_3 --> 2.1.10-h9b69904_4
#   libgcc-ng                               9.3.0-h2828fa1_18 --> 11.2.0-h1d223b6_11
#   libgfortran-ng                          9.3.0-hff62375_18 --> 11.2.0-h69a702a_11
#   libgfortran5                            9.3.0-hff62375_18 --> 11.2.0-h5c6108e_11
#   libgomp                                 9.3.0-h2828fa1_18 --> 11.2.0-h1d223b6_11
#   liblapack                                3.9.0-8_openblas --> 3.9.0-12_linux64_openblas
#   libllvm11                               11.0.1-hf817b99_0 --> 11.1.0-hf817b99_2
#   libnghttp2                              1.43.0-h812cca2_0 --> 1.43.0-h812cca2_1
#   libopenblas                    0.3.12-pthreads_h4812303_1 --> 0.3.18-pthreads_h8fe5266_0
#   libpq                                     13.1-hfd2b0eb_1 --> 13.3-hd57d9b9_3
#   libprotobuf                             3.15.2-h780b84a_0 --> 3.19.1-h780b84a_0
#   libspatialindex                          1.9.3-h9c3ff4c_3 --> 1.9.3-h9c3ff4c_4
#   libssh2                                  1.9.0-hab1572f_5 --> 1.10.0-ha56f1ee_2
#   libstdcxx-ng                            9.3.0-h6de172a_18 --> 11.2.0-he4da1e4_11
#   libtiff                                  4.2.0-hdc55705_0 --> 4.3.0-h6f004c6_2
#   libtool                               2.4.6-h58526e2_1007 --> 2.4.6-h9c3ff4c_1008
#   libuv                                   1.41.0-h7f98852_0 --> 1.42.0-h7f98852_0
#   libwebp                                  1.2.0-h3452ae3_0 --> 1.2.1-h3452ae3_0
#   libwebp-base                             1.2.0-h7f98852_0 --> 1.2.1-h7f98852_0
#   libxcb                                 1.13-h7f98852_1003 --> 1.13-h7f98852_1004
#   libxml2                                 2.9.10-h72842e0_3 --> 2.9.12-h72842e0_0
#   lz4-c                                    1.9.3-h9c3ff4c_0 --> 1.9.3-h9c3ff4c_1
#   markupsafe                           1.1.1-py36h8f6f2f9_3 --> 2.0.1-py36h8f6f2f9_0
#   mistune                           0.8.4-py36h8f6f2f9_1003 --> 0.8.4-py36h8f6f2f9_1004
#   mkl                             pkgs/main::mkl-2020.2-256 --> conda-forge::mkl-2020.4-h726a3e6_304
#   more-itertools                         8.7.0-pyhd8ed1ab_0 --> 8.11.0-pyhd8ed1ab_0
#   mpc                                   1.1.0-h04dde30_1009 --> 1.2.1-h9f54685_0
#   mpfr                                     4.0.2-he80fd80_1 --> 4.1.0-h9202a9a_1
#   multidict                            5.1.0-py36h8f6f2f9_1 --> 5.2.0-py36h8f6f2f9_0
#   mysql-common                            8.0.23-ha770c72_1 --> 8.0.27-ha770c72_1
#   mysql-libs                              8.0.23-h935591d_1 --> 8.0.27-hfa10184_1
#   nest-asyncio                           1.4.3-pyhd8ed1ab_0 --> 1.5.1-pyhd8ed1ab_0
#   networkx                                         2.5-py_0 --> 2.6.3-pyhd8ed1ab_1
#   nspr                                      4.29-h9c3ff4c_1 --> 4.32-h9c3ff4c_1
#   nss                                       3.62-hb5efdd6_0 --> 3.72-hb5efdd6_0
#   numexpr                              2.7.2-py36h284efc9_0 --> 2.7.3-py36h0cdc3f0_0
#   numpy                               1.19.5-py36h2aa4a07_1 --> 1.19.5-py36hfc0c790_2
#   openpyxl                               3.0.6-pyhd8ed1ab_0 --> 3.0.9-pyhd8ed1ab_0
#   openssl                                 1.1.1k-h7f98852_0 --> 1.1.1l-h7f98852_0
#   packaging                               20.9-pyh44b312d_0 --> 21.2-pyhd8ed1ab_1
#   pandoc                                  2.11.4-h7f98852_0 --> 2.16.1-h7f98852_0
#   pandocfilters                                  1.4.2-py_1 --> 1.5.0-pyhd8ed1ab_0
#   partd                                          1.1.0-py_0 --> 1.2.0-pyhd8ed1ab_0
#   patchelf                                  0.11-he1b5a44_0 --> 0.13-h58526e2_0
#   pathlib2                             2.3.5-py36h5fab9bb_3 --> 2.3.6-py36h5fab9bb_0
#   pathspec                               0.8.1-pyhd3deb0d_0 --> 0.9.0-pyhd8ed1ab_0
#   patsy                                          0.5.1-py_0 --> 0.5.2-pyhd8ed1ab_0
#   pcre                                      8.44-he1b5a44_0 --> 8.45-h9c3ff4c_0
#   pkginfo                                1.7.0-pyhd8ed1ab_0 --> 1.7.1-pyhd8ed1ab_0
#   prometheus_client                      0.9.0-pyhd3deb0d_0 --> 0.12.0-pyhd8ed1ab_0
#   prompt-toolkit                                 3.0.5-py_0 --> 3.0.22-pyha770c72_0
#   prompt_toolkit                                1.0.15-py_1 --> 3.0.22-hd8ed1ab_0
#   py                                    1.10.0-pyhd3deb0d_0 --> 1.11.0-pyh6c4a22f_0
#   pycparser                               2.20-pyh9f0ad1d_2 --> 2.21-pyhd8ed1ab_0
#   pycurl                            7.43.0.6-py36h66a4f8d_1 --> 7.44.1-py36h66a4f8d_0
#   pydocstyle                                     5.1.1-py_0 --> 6.1.1-pyhd8ed1ab_0
#   pygments                               2.8.0-pyhd8ed1ab_0 --> 2.10.0-pyhd8ed1ab_0
#   pyodbc                              4.0.30-py36hc4f0c31_1 --> 4.0.32-py36hc4f0c31_0
#   pyopenssl                             20.0.1-pyhd8ed1ab_0 --> 21.0.0-pyhd8ed1ab_0
#   pyparsing                              2.4.7-pyh9f0ad1d_0 --> 2.4.7-pyhd8ed1ab_1
#   python-dateutil                                2.8.1-py_0 --> 2.8.2-pyhd8ed1ab_0
#   python_abi                                    3.6-1_cp36m --> 3.6-2_cp36m
#   pytz                                  2021.1-pyhd8ed1ab_0 --> 2021.3-pyhd8ed1ab_0
#   pyxdg                                           0.26-py_0 --> 0.27-pyhd8ed1ab_0
#   pyyaml                               5.4.1-py36h8f6f2f9_0 --> 5.4.1-py36h8f6f2f9_1
#   pyzmq                               22.0.3-py36h81c33ee_0 --> 22.3.0-py36h7068817_0
#   qtawesome                              1.0.2-pyhd8ed1ab_0 --> 1.1.0-pyhd8ed1ab_0
#   qtconsole                              5.0.2-pyhd8ed1ab_0 --> 5.2.0-pyhd8ed1ab_0
#   qtpy                                           1.9.0-py_0 --> 1.11.2-pyhd8ed1ab_0
#   readline                                   8.0-he28a2e2_2 --> 8.1-h46c0cb4_0
#   rope                                  0.18.0-pyh9f0ad1d_0 --> 0.21.1-pyhd8ed1ab_0
#   scikit-learn                        0.24.1-py36he4fde30_0 --> 0.24.2-py36hc89565f_1
#   scipy                                1.5.3-py36h9e8f40b_0 --> 1.5.3-py36h81d768a_1
#   send2trash                                     1.5.0-py_0 --> 1.8.0-pyhd8ed1ab_0
#   singledispatch                         3.6.0-pyh44b312d_0 --> 3.6.1-pyh44b312d_0
#   sip                                4.19.24-py36hc4f0c31_3 --> 4.19.25-py36hc4f0c31_0
#   six                                   1.15.0-pyh9f0ad1d_0 --> 1.16.0-pyh6c4a22f_0
#   sortedcontainers                       2.3.0-pyhd8ed1ab_0 --> 2.4.0-pyhd8ed1ab_0
#   soupsieve                                      2.0.1-py_1 --> 2.3-pyhd8ed1ab_0
#   sphinxcontrib-htm~                             1.0.3-py_0 --> 2.0.0-pyhd8ed1ab_0
#   sphinxcontrib-ser~                             1.1.4-py_0 --> 1.1.5-pyhd8ed1ab_0
#   sqlite                                  3.34.0-h74cdb3f_0 --> 3.36.0-h9cd32fc_2
#   sympy                                1.7.1-py36h5fab9bb_1 --> 1.8-py36h5fab9bb_0
#   tblib                                          1.6.0-py_0 --> 1.7.0-pyhd8ed1ab_0
#   terminado                            0.9.2-py36h5fab9bb_0 --> 0.12.1-py36h5fab9bb_0
#   testpath                                       0.4.4-py_0 --> 0.5.0-pyhd8ed1ab_0
#   threadpoolctl                          2.1.0-pyh5ca1d4c_0 --> 3.0.0-pyh8a188c0_0
#   tk                                      8.6.10-h21135ba_1 --> 8.6.11-h27826a3_1
#   toolz                                         0.11.1-py_0 --> 0.11.2-pyhd8ed1ab_0
#   traitlets          conda-forge/linux-64::traitlets-4.3.3~ --> conda-forge/noarch::traitlets-4.3.3-pyhd8ed1ab_2
#   typed-ast                            1.4.2-py36h8f6f2f9_0 --> 1.4.3-py36h8f6f2f9_0
#   typing                               3.7.4.3-pyhd8ed1ab_2 --> 3.10.0.0-pyhd8ed1ab_0
#   typing-extensions                               3.7.4.3-0 --> 3.10.0.2-hd8ed1ab_0
#   ujson                                4.0.2-py36hc4f0c31_0 --> 4.2.0-py36hc4f0c31_0
#   watchdog                             2.0.2-py36h5fab9bb_0 --> 2.1.6-py36h5fab9bb_0
#   werkzeug                               1.0.1-pyh9f0ad1d_0 --> 2.0.1-pyhd8ed1ab_0
#   wheel                                 0.36.2-pyhd3deb0d_0 --> 0.37.0-pyhd8ed1ab_1
#   wurlitzer                            2.0.1-py36h5fab9bb_1 --> 3.0.2-py36h5fab9bb_0
#   xlsxwriter                             1.3.7-pyh9f0ad1d_0 --> 3.0.2-pyhd8ed1ab_0
#   xorg-libx11                             1.6.12-h516909a_0 --> 1.7.2-h7f98852_0
#   xorg-libxext                             1.3.4-h516909a_0 --> 1.3.4-h7f98852_1
#   xorg-libxrender                      0.9.10-h516909a_1002 --> 0.9.10-h7f98852_1003
#   yapf                                  0.30.0-pyh9f0ad1d_0 --> 0.31.0-pyhd8ed1ab_0
#   zeromq                                   4.3.4-h9c3ff4c_0 --> 4.3.4-h9c3ff4c_1
#   zipp                                           3.4.0-py_0 --> 3.6.0-pyhd8ed1ab_0
#   zlib                                 1.2.11-h516909a_1010 --> 1.2.11-h36c2ea0_1013
#   zope.interface                       5.2.0-py36h8f6f2f9_1 --> 5.4.0-py36h8f6f2f9_0
#   zstd                                     1.4.8-ha95c52a_1 --> 1.5.0-ha95c52a_0
#
# The following packages will be DOWNGRADED:
#
#   _openmp_mutex                                   4.5-1_gnu --> 4.5-1_llvm
#   protobuf                            3.15.2-py36hc4f0c31_0 --> 3.4.1-py36_0
#   unixodbc                                 2.3.9-h0e019cf_0 --> 2.3.9-hb166930_0
#   xorg-libice                             1.0.10-h516909a_0 --> 1.0.10-h7f98852_0
#   xorg-libsm                            1.2.3-h84519dc_1000 --> 1.2.3-hd9c2040_1000
#   xorg-renderproto                     0.11.1-h14c3975_1002 --> 0.11.1-h7f98852_1002
#
#
#
# Downloading and Extracting Packages
# notebook-6.3.0       | 6.3 MB    | ##################################### | 100%
# ujson-4.2.0          | 48 KB     | ##################################### | 100%
# contextlib2-21.6.0   | 16 KB     | ##################################### | 100%
# prompt-toolkit-3.0.2 | 249 KB    | ##################################### | 100%
# imagesize-1.3.0      | 9 KB      | ##################################### | 100%
# krb5-1.19.2          | 1.4 MB    | ##################################### | 100%
# qtawesome-1.1.0      | 2.0 MB    | ##################################### | 100%
# async-timeout-4.0.0  | 9 KB      | ##################################### | 100%
# cycler-0.11.0        | 10 KB     | ##################################### | 100%
# pyodbc-4.0.32        | 75 KB     | ##################################### | 100%
# dataclasses-0.8      | 22 KB     | ##################################### | 100%
# mysql-common-8.0.27  | 1.8 MB    | ##################################### | 100%
# fsspec-2021.11.0     | 91 KB     | ##################################### | 100%
# threadpoolctl-3.0.0  | 17 KB     | ##################################### | 100%
# bottleneck-1.3.2     | 129 KB    | ##################################### | 100%
# deprecation-2.1.0    | 14 KB     | ##################################### | 100%
# protobuf-3.4.1       | 5.6 MB    | ##################################### | 100%
# intel-openmp-2021.4. | 4.2 MB    | ##################################### | 100%
# libprotobuf-3.19.1   | 2.6 MB    | ##################################### | 100%
# prompt_toolkit-3.0.2 | 5 KB      | ##################################### | 100%
# watchdog-2.1.6       | 94 KB     | ##################################### | 100%
# py-1.11.0            | 74 KB     | ##################################### | 100%
# mpfr-4.1.0           | 2.6 MB    | ##################################### | 100%
# libnghttp2-1.43.0    | 790 KB    | ##################################### | 100%
# cloudpickle-2.0.0    | 24 KB     | ##################################### | 100%
# nspr-4.32            | 233 KB    | ##################################### | 100%
# qtconsole-5.2.0      | 90 KB     | ##################################### | 100%
# pycparser-2.21       | 100 KB    | ##################################### | 100%
# patchelf-0.13        | 84 KB     | ##################################### | 100%
# libcurl-7.80.0       | 337 KB    | ##################################### | 100%
# charset-normalizer-2 | 32 KB     | ##################################### | 100%
# isort-5.10.1         | 79 KB     | ##################################### | 100%
# immutables-0.16      | 65 KB     | ##################################### | 100%
# pycurl-7.44.1        | 70 KB     | ##################################### | 100%
# ipyparallel-8.0.0    | 243 KB    | ##################################### | 100%
# rope-0.21.1          | 122 KB    | ##################################### | 100%
# lxml-3.8.0           | 3.8 MB    | ##################################### | 100%
# more-itertools-8.11. | 47 KB     | ##################################### | 100%
# mpc-1.2.1            | 106 KB    | ##################################### | 100%
# argon2-cffi-21.1.0   | 46 KB     | ##################################### | 100%
# scipy-1.5.3          | 19.1 MB   | ##################################### | 100%
# libspatialindex-1.9. | 4.6 MB    | ##################################### | 100%
# jupyter-packaging-0. | 17 KB     | ##################################### | 100%
# mkl-2020.4           | 215.6 MB  | ##################################### | 100%
# bitarray-2.3.4       | 139 KB    | ##################################### | 100%
# mysql-libs-8.0.27    | 1.9 MB    | ##################################### | 100%
# tqdm-4.62.3          | 80 KB     | ##################################### | 100%
# packaging-21.2       | 35 KB     | ##################################### | 100%
# networkx-2.6.3       | 1.5 MB    | ##################################### | 100%
# openpyxl-3.0.9       | 153 KB    | ##################################### | 100%
# cython-0.29.24       | 2.2 MB    | ##################################### | 100%
# joblib-1.1.0         | 210 KB    | ##################################### | 100%
# tomlkit-0.7.2        | 30 KB     | ##################################### | 100%
# pathspec-0.9.0       | 31 KB     | ##################################### | 100%
# pyyaml-5.4.1         | 194 KB    | ##################################### | 100%
# toolz-0.11.2         | 48 KB     | ##################################### | 100%
# pkginfo-1.7.1        | 22 KB     | ##################################### | 100%
# curl-7.80.0          | 153 KB    | ##################################### | 100%
# pylint-2.7.2         | 466 KB    | ##################################### | 100%
# nss-3.72             | 2.1 MB    | ##################################### | 100%
# _openmp_mutex-4.5    | 5 KB      | ##################################### | 100%
# flask-cors-3.0.10    | 15 KB     | ##################################### | 100%
# libxcb-1.13          | 391 KB    | ##################################### | 100%
# pyparsing-2.4.7      | 60 KB     | ##################################### | 100%
# cached-property-1.5. | 4 KB      | ##################################### | 100%
# jeepney-0.7.1        | 38 KB     | ##################################### | 100%
# libpq-13.3           | 2.7 MB    | ##################################### | 100%
# pathlib2-2.3.6       | 35 KB     | ##################################### | 100%
# pillow-7.2.0         | 679 KB    | ##################################### | 100%
# numexpr-2.7.3        | 200 KB    | ##################################### | 100%
# icu-68.2             | 13.1 MB   | ##################################### | 100%
# xlsxwriter-3.0.2     | 108 KB    | ##################################### | 100%
# requests-2.26.0      | 52 KB     | ##################################### | 100%
# c-ares-1.18.1        | 113 KB    | ##################################### | 100%
# pandoc-2.16.1        | 12.6 MB   | ##################################### | 100%
# prometheus_client-0. | 47 KB     | ##################################### | 100%
# jupyterlab-3.2.3     | 6.0 MB    | ##################################### | 100%
# jinja2-3.0.3         | 99 KB     | ##################################### | 100%
# wurlitzer-3.0.2      | 15 KB     | ##################################### | 100%
# llvm-openmp-12.0.1   | 2.8 MB    | ##################################### | 100%
# soupsieve-2.3        | 33 KB     | ##################################### | 100%
# typing-3.10.0.0      | 7 KB      | ##################################### | 100%
# flask-2.0.2          | 70 KB     | ##################################### | 100%
# patsy-0.5.2          | 188 KB    | ##################################### | 100%
# scikit-learn-0.24.2  | 7.5 MB    | ##################################### | 100%
# idna_ssl-1.1.0       | 7 KB      | ##################################### | 100%
# filelock-3.3.2       | 12 KB     | ##################################### | 100%
# beautifulsoup4-4.10. | 77 KB     | ##################################### | 100%
# libssh2-1.10.0       | 233 KB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
#step 3
import pandas as pd
from sklearn.manifold import TSNE
time_start = time.time()
tsne = TSNE(n_components=2, verbose=1, perplexity=50, n_iter=5000)
tsne_results = tsne.fit_transform(predictions)
print('t-SNE done! Time elapsed: {} seconds'.format(time.time()-time_start))
tsnedf = pd.DataFrame()
tsnedf['tsne-2d-one'] = tsne_results[:,0]
tsnedf['tsne-2d-two'] = tsne_results[:,1]
tsnedf['Topic']=topicnames
plt.figure(figsize=(25,25))
sns.lmplot(
    x="tsne-2d-one", y="tsne-2d-two",
    hue='Topic',
    palette=sns.color_palette("hls", NUM_TOPICS),
    data=tsnedf,
    legend="full",
    fit_reg=False
)
plt.axis('Off')
plt.show()
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 11314 samples in 0.038s...
# [t-SNE] Computed neighbors for 11314 samples in 2.603s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 11314
# [t-SNE] Computed conditional probabilities for sample 2000 / 11314
# [t-SNE] Computed conditional probabilities for sample 3000 / 11314
# [t-SNE] Computed conditional probabilities for sample 4000 / 11314
# [t-SNE] Computed conditional probabilities for sample 5000 / 11314
# [t-SNE] Computed conditional probabilities for sample 6000 / 11314
# [t-SNE] Computed conditional probabilities for sample 7000 / 11314
# [t-SNE] Computed conditional probabilities for sample 8000 / 11314
# [t-SNE] Computed conditional probabilities for sample 9000 / 11314
# [t-SNE] Computed conditional probabilities for sample 10000 / 11314
# [t-SNE] Computed conditional probabilities for sample 11000 / 11314
# [t-SNE] Computed conditional probabilities for sample 11314 / 11314
# [t-SNE] Mean sigma: 0.000000
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 77.901047
# [t-SNE] KL divergence after 5000 iterations: 1.301854
# t-SNE done! Time elapsed: 421.56521701812744 seconds
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-f0cebb69f82f> in <module>
#       9 tsnedf['tsne-2d-one'] = tsne_results[:,0]
#      10 tsnedf['tsne-2d-two'] = tsne_results[:,1]
# ---> 11 tsnedf['Topic']=topicnames
#      12 plt.figure(figsize=(25,25))
#      13 sns.lmplot(
#
# NameError: name 'topicnames' is not defined

# %%
labels = newidx 
labeldict = dict(zip(newidx,idx))

# %%
import io
import sagemaker.amazon.common as smac


print('train_features shape = ', predictions.shape)
print('train_labels shape = ', labels.shape)
buf = io.BytesIO()
smac.write_numpy_to_dense_tensor(buf, predictions, labels)
buf.seek(0)

bucket = BUCKET
prefix = PREFIX
key = 'knn/train'
fname = os.path.join(prefix, key)
print(fname)
boto3.resource('s3').Bucket(bucket).Object(fname).upload_fileobj(buf)
s3_train_data = 's3://{}/{}/{}'.format(bucket, prefix, key)
print('uploaded training data location: {}'.format(s3_train_data))
# Out:
# train_features shape =  (11314, 30)
# train_labels shape =  (11314,)
# 20newsgroups/knn/train
# uploaded training data location: s3://sagemaker-crsmids/20newsgroups/knn/train

# %%
def trained_estimator_from_hyperparams(s3_train_data, hyperparams, output_path, s3_test_data=None):
    """
    Create an Estimator from the given hyperparams, fit to training data, 
    and return a deployed predictor
    
    """
    # set up the estimator
    knn = sagemaker.estimator.Estimator(get_image_uri(boto3.Session().region_name, "knn"),
        get_execution_role(),
        train_instance_count=1,
        train_instance_type='ml.c4.xlarge',
        output_path=output_path,
        sagemaker_session=sagemaker.Session())
    knn.set_hyperparameters(**hyperparams)
    
    # train a model. fit_input contains the locations of the train and test data
    fit_input = {'train': s3_train_data}
    knn.fit(fit_input)
    return knn

hyperparams = {
    'feature_dim': predictions.shape[1],
    'k': NUM_NEIGHBORS,
    'sample_size': predictions.shape[0],
    'predictor_type': 'classifier' ,
    'index_metric':'COSINE'
}
output_path = 's3://' + bucket + '/' + prefix + '/knn/output'
knn_estimator = trained_estimator_from_hyperparams(s3_train_data, hyperparams, output_path)
# Out:
# The method get_image_uri has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# Defaulting to the only supported framework/algorithm version: 1. Ignoring framework/algorithm version: 1.
# train_instance_count has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# train_instance_type has been renamed in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# 2021-11-13 22:49:22 Starting - Starting the training job...
# 2021-11-13 22:49:24 Starting - Launching requested ML instancesProfilerReport-1636843762: InProgress
# ......
# 2021-11-13 22:50:39 Starting - Preparing the instances for training.........
# 2021-11-13 22:52:20 Downloading - Downloading input data
# 2021-11-13 22:52:20 Training - Downloading the training image...........Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [11/13/2021 22:53:58 INFO 139994232256320] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-conf.json: {'_kvstore': 'dist_async', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_tuning_objective_metric': '', '_faiss_index_nprobe': '5', 'epochs': '1', 'feature_dim': 'auto', 'faiss_index_ivf_nlists': 'auto', 'index_metric': 'L2', 'index_type': 'faiss.Flat', 'mini_batch_size': '5000', '_enable_profiler': 'false'}
# [11/13/2021 22:53:58 INFO 139994232256320] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '30', 'predictor_type': 'classifier', 'sample_size': '11314', 'index_metric': 'COSINE', 'k': '10'}
# [11/13/2021 22:53:58 INFO 139994232256320] Final configuration: {'_kvstore': 'dist_async', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_tuning_objective_metric': '', '_faiss_index_nprobe': '5', 'epochs': '1', 'feature_dim': '30', 'faiss_index_ivf_nlists': 'auto', 'index_metric': 'COSINE', 'index_type': 'faiss.Flat', 'mini_batch_size': '5000', '_enable_profiler': 'false', 'predictor_type': 'classifier', 'sample_size': '11314', 'k': '10'}
# [11/13/2021 22:54:04 WARNING 139994232256320] Loggers have already been setup.
# [11/13/2021 22:54:04 INFO 139994232256320] Final configuration: {'_kvstore': 'dist_async', '_log_level': 'info', '_num_gpus': 'auto', '_num_kv_servers': '1', '_tuning_objective_metric': '', '_faiss_index_nprobe': '5', 'epochs': '1', 'feature_dim': '30', 'faiss_index_ivf_nlists': 'auto', 'index_metric': 'COSINE', 'index_type': 'faiss.Flat', 'mini_batch_size': '5000', '_enable_profiler': 'false', 'predictor_type': 'classifier', 'sample_size': '11314', 'k': '10'}
# [11/13/2021 22:54:04 WARNING 139994232256320] Loggers have already been setup.
# [11/13/2021 22:54:05 INFO 139994232256320] Launching parameter server for role scheduler
# [11/13/2021 22:54:05 INFO 139994232256320] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-190-104.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'knn-2021-11-13-22-49-22-683', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/knn-2021-11-13-22-49-22-683', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/2b731032-2d80-4abd-9e80-71197464e40d', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/5462f538-5657-45dc-b701-e2133a4db516', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/5462f538-5657-45dc-b701-e2133a4db516', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [11/13/2021 22:54:05 INFO 139994232256320] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-190-104.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'knn-2021-11-13-22-49-22-683', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/knn-2021-11-13-22-49-22-683', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/2b731032-2d80-4abd-9e80-71197464e40d', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/5462f538-5657-45dc-b701-e2133a4db516', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/5462f538-5657-45dc-b701-e2133a4db516', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'scheduler', 'DMLC_PS_ROOT_URI': '10.0.190.104', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [11/13/2021 22:54:05 INFO 139994232256320] Launching parameter server for role server
# [11/13/2021 22:54:05 INFO 139994232256320] {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-190-104.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'knn-2021-11-13-22-49-22-683', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/knn-2021-11-13-22-49-22-683', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/2b731032-2d80-4abd-9e80-71197464e40d', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/5462f538-5657-45dc-b701-e2133a4db516', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/5462f538-5657-45dc-b701-e2133a4db516', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml'}
# [11/13/2021 22:54:05 INFO 139994232256320] envs={'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-190-104.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'knn-2021-11-13-22-49-22-683', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/knn-2021-11-13-22-49-22-683', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/2b731032-2d80-4abd-9e80-71197464e40d', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/5462f538-5657-45dc-b701-e2133a4db516', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/5462f538-5657-45dc-b701-e2133a4db516', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'server', 'DMLC_PS_ROOT_URI': '10.0.190.104', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# [11/13/2021 22:54:05 INFO 139994232256320] Environment: {'ENVROOT': '/opt/amazon', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'HOSTNAME': 'ip-10-0-190-104.us-east-2.compute.internal', 'TRAINING_JOB_NAME': 'knn-2021-11-13-22-49-22-683', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:153869151158:training-job/knn-2021-11-13-22-49-22-683', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/2b731032-2d80-4abd-9e80-71197464e40d', 'CANONICAL_ENVROOT': '/opt/amazon', 'PYTHONUNBUFFERED': 'TRUE', 'NVIDIA_VISIBLE_DEVICES': 'void', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python3.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PWD': '/', 'LANG': 'en_US.utf8', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'HOME': '/root', 'SHLVL': '1', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'OMP_NUM_THREADS': '2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/5462f538-5657-45dc-b701-e2133a4db516', 'DMLC_INTERFACE': 'eth0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/5462f538-5657-45dc-b701-e2133a4db516', 'SAGEMAKER_HTTP_PORT': '8080', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'DMLC_ROLE': 'worker', 'DMLC_PS_ROOT_URI': '10.0.190.104', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_SERVER': '1', 'DMLC_NUM_WORKER': '1'}
# Process 49 is a shell:scheduler.
# Process 61 is a shell:server.
# Process 1 is a worker.
# [11/13/2021 22:54:05 INFO 139994232256320] Using default worker.
# [11/13/2021 22:54:05 INFO 139994232256320] Checkpoint loading and saving are disabled.
# [11/13/2021 22:54:05 INFO 139994232256320] nvidia-smi: took 0.036 seconds to run.
# [11/13/2021 22:54:05 INFO 139994232256320] nvidia-smi identified 0 GPUs.
# [11/13/2021 22:54:05 INFO 139994232256320] Create Store: dist_async
# [22:54:05] ../src/base.cc:47: Please install cuda driver for GPU use.  No cuda driver detected.
# [22:54:06] ../src/base.cc:47: Please install cuda driver for GPU use.  No cuda driver detected.
# [22:54:06] ../src/base.cc:47: Please install cuda driver for GPU use.  No cuda driver detected.
# [11/13/2021 22:54:06 ERROR 139994232256320] nvidia-smi: failed to run (127): b'/bin/sh: nvidia-smi: command not found'/
# [11/13/2021 22:54:06 WARNING 139994232256320] Could not determine free memory in MB for GPU device with ID (0).
# [11/13/2021 22:54:06 INFO 139994232256320] Using per-worker sample size = 11314 (Available virtual memory = 6051811328 bytes, GPU free memory = 0 bytes, number of workers = 1). If an out-of-memory error occurs, choose a larger instance type, use dimension reduction, decrease sample_size, and/or decrease mini_batch_size.
# [11/13/2021 22:54:06 INFO 139994232256320] Starting cluster...
# [11/13/2021 22:54:06 INFO 139992320706304] concurrency model: async
# [11/13/2021 22:54:06 INFO 139992320706304] masquerade (NAT) address: None
# [11/13/2021 22:54:06 INFO 139992320706304] passive ports: None
# [11/13/2021 22:54:06 INFO 139992320706304] >>> starting FTP server on 0.0.0.0:8999, pid=1 <<<
# [11/13/2021 22:54:06 INFO 139994232256320] ...Cluster started
# [11/13/2021 22:54:06 INFO 139994232256320] Verifying connection to 0 peer cluster(s)...
# [11/13/2021 22:54:06 INFO 139994232256320] ...Verified connection to 0 peer cluster(s)
# #metrics {"StartTime": 1636844046.5077076, "EndTime": 1636844046.5077505, "Dimensions": {"Algorithm": "AWS/KNN", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Total Batches Seen": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Records Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Max Batches Seen Between Resets": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Reset Count": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
# [2021-11-13 22:54:06.508] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 911, "num_examples": 1, "num_bytes": 1440000}
# [2021-11-13 22:54:06.824] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 315, "num_examples": 3, "num_bytes": 3258432}
# [11/13/2021 22:54:06 INFO 139994232256320] #progress_metric: host=algo-1, completed 100.0 % of epochs
# #metrics {"StartTime": 1636844046.508347, "EndTime": 1636844046.832848, "Dimensions": {"Algorithm": "AWS/KNN", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 11314.0, "count": 1, "min": 11314, "max": 11314}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 11314.0, "count": 1, "min": 11314, "max": 11314}, "Max Batches Seen Between Resets": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Reset Count": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "Number of Records Since Last Reset": {"sum": 11314.0, "count": 1, "min": 11314, "max": 11314}, "Number of Batches Since Last Reset": {"sum": 3.0, "count": 1, "min": 3, "max": 3}}}
# [11/13/2021 22:54:06 INFO 139994232256320] #throughput_metric: host=algo-1, train throughput=34849.39792523746 records/second
# [11/13/2021 22:54:06 INFO 139994232256320] Getting reservoir sample from algo-1...
# [11/13/2021 22:54:06 INFO 139992320706304] 10.0.190.104:41312-[] FTP session opened (connect)
# [11/13/2021 22:54:06 INFO 139992320706304] 10.0.190.104:41312-[anonymous] USER 'anonymous' logged in.
# [11/13/2021 22:54:06 INFO 139992320706304] 10.0.190.104:41312-[anonymous] RETR /opt/rs completed=1 bytes=1493652 seconds=0.001
# [11/13/2021 22:54:06 INFO 139992320706304] 10.0.190.104:41312-[anonymous] FTP session closed (disconnect).
# [11/13/2021 22:54:06 INFO 139994232256320] ...Got reservoir sample from algo-1: data=(11314, 30), labels=(11314,), NaNs=0
# [11/13/2021 22:54:06 INFO 139994232256320] Training index...
# [11/13/2021 22:54:06 INFO 139994232256320] ...Finished training index in 0 second(s)
# [11/13/2021 22:54:06 INFO 139994232256320] Adding data to index...
# [11/13/2021 22:54:06 INFO 139994232256320] ...Finished adding data to index in 0 second(s)
# #metrics {"StartTime": 1636844045.5957282, "EndTime": 1636844046.8928218, "Dimensions": {"Algorithm": "AWS/KNN", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 895.5202102661133, "count": 1, "min": 895.5202102661133, "max": 895.5202102661133}, "epochs": {"sum": 1.0, "count": 1, "min": 1, "max": 1}, "update.time": {"sum": 324.2347240447998, "count": 1, "min": 324.2347240447998, "max": 324.2347240447998}, "finalize.time": {"sum": 53.017377853393555, "count": 1, "min": 53.017377853393555, "max": 53.017377853393555}, "model.serialize.time": {"sum": 6.51860237121582, "count": 1, "min": 6.51860237121582, "max": 6.51860237121582}}}
# [11/13/2021 22:54:06 INFO 139994232256320] Test data is not provided.
# [11/13/2021 22:54:06 INFO 139992320706304] >>> shutting down FTP server, 0 socket(s), pid=1 <<<
# #metrics {"StartTime": 1636844046.892916, "EndTime": 1636844046.941892, "Dimensions": {"Algorithm": "AWS/KNN", "Host": "algo-1", "Operation": "training"}, "Metrics": {"setuptime": {"sum": 19.84262466430664, "count": 1, "min": 19.84262466430664, "max": 19.84262466430664}, "totaltime": {"sum": 1946.5584754943848, "count": 1, "min": 1946.5584754943848, "max": 1946.5584754943848}}}
#
# 2021-11-13 22:54:20 Uploading - Uploading generated training model
# 2021-11-13 22:54:20 Completed - Training job completed
# Training seconds: 132
# Billable seconds: 132

# %%
pip install -U sagemaker
# Out:
# Requirement already satisfied: sagemaker in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (2.69.0)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (4.8.1)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.1.5)
# Requirement already satisfied: smdebug-rulesconfig==1.0.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.0.1)
# Requirement already satisfied: pathos in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.8)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.19.5)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (3.19.0)
# Requirement already satisfied: boto3>=1.16.32 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.19.3)
# Requirement already satisfied: google-pasta in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (0.2.0)
# Requirement already satisfied: attrs in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (21.2.0)
# Requirement already satisfied: pandas in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (1.1.5)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from sagemaker) (21.2)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.10.0)
# Requirement already satisfied: botocore<1.23.0,>=1.22.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (1.22.3)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from boto3>=1.16.32->sagemaker) (0.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker) (3.6.0)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from packaging>=20.0->sagemaker) (2.4.7)
# Requirement already satisfied: six in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from protobuf3-to-dict>=0.1.5->sagemaker) (1.16.0)
# Requirement already satisfied: pytz>=2017.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->sagemaker) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pandas->sagemaker) (2.8.2)
# Requirement already satisfied: dill>=0.3.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.3.4)
# Requirement already satisfied: pox>=0.3.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.3.0)
# Requirement already satisfied: ppft>=1.6.6.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (1.6.6.4)
# Requirement already satisfied: multiprocess>=0.70.12 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pathos->sagemaker) (0.70.12.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from botocore<1.23.0,>=1.22.3->boto3>=1.16.32->sagemaker) (1.26.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
def predictor_from_estimator(knn_estimator, estimator_name, instance_type, endpoint_name=None): 
    knn_predictor = knn_estimator.deploy(initial_instance_count=1, instance_type=instance_type,
                                        endpoint_name=endpoint_name)
    #knn_predictor.content_type = 'text/csv'
    knn_predictor.serializer = csv_serializer
    knn_predictor.deserializer = json_deserializer
    return knn_predictor
import time

instance_type = 'ml.m4.xlarge'
model_name = 'knn_%s'% instance_type
endpoint_name = 'knn-ml-m4-xlarge-%s'% (str(time.time()).replace('.','-'))
print('setting up the endpoint..')
knn_predictor = predictor_from_estimator(knn_estimator, model_name, instance_type, endpoint_name=endpoint_name)
# Out:
# setting up the endpoint..
# ---------------------------------------------------------------------------
# ResourceLimitExceeded                     Traceback (most recent call last)
# <ipython-input-73-0a4bc3a126a4> in <module>
#      12 endpoint_name = 'knn-ml-m4-xlarge-%s'% (str(time.time()).replace('.','-'))
#      13 print('setting up the endpoint..')
# ---> 14 knn_predictor = predictor_from_estimator(knn_estimator, model_name, instance_type, endpoint_name=endpoint_name)
#
# <ipython-input-73-0a4bc3a126a4> in predictor_from_estimator(knn_estimator, estimator_name, instance_type, endpoint_name)
#       1 def predictor_from_estimator(knn_estimator, estimator_name, instance_type, endpoint_name=None):
#       2     knn_predictor = knn_estimator.deploy(initial_instance_count=1, instance_type=instance_type,
# ----> 3                                         endpoint_name=endpoint_name)
#       4     #knn_predictor.content_type = 'text/csv'
#       5     knn_predictor.serializer = csv_serializer
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/estimator.py in deploy(self, initial_instance_count, instance_type, serializer, deserializer, accelerator_type, endpoint_name, use_compiled_model, wait, model_name, kms_key, data_capture_config, tags, **kwargs)
#     963
#     964     def register(
# --> 965         self,
#     966         content_types,
#     967         response_types,
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/model.py in deploy(self, initial_instance_count, instance_type, serializer, deserializer, accelerator_type, endpoint_name, tags, kms_key, wait, data_capture_config, **kwargs)
#     731             tags (List[dict[str, str]]): The list of tags to attach to this
#     732                 specific endpoint.
# --> 733             kms_key (str): The ARN of the KMS key that is used to encrypt the
#     734                 data on the storage volume attached to the instance hosting the
#     735                 endpoint.
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in endpoint_from_production_variants(self, name, production_variants, tags, kms_key, wait, data_capture_config_dict)
#    3516             lambda: self.sagemaker_client.describe_endpoint_config(EndpointConfigName=name)
#    3517         ):
# -> 3518             self.create_endpoint_config(
#    3519                 name=name,
#    3520                 model_name=name,
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/sagemaker/session.py in create_endpoint(self, endpoint_name, config_name, tags, wait)
#    3016
#    3017         existing_endpoint_config_desc = self.sagemaker_client.describe_endpoint_config(
# -> 3018             EndpointConfigName=existing_config_name
#    3019         )
#    3020
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     386                     "%s() only accepts keyword arguments." % py_operation_name)
#     387             # The "self" in this scope is referring to the BaseClient.
# --> 388             return self._make_api_call(operation_name, kwargs)
#     389
#     390         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     706             error_code = parsed_response.get("Error", {}).get("Code")
#     707             error_class = self.exceptions.from_code(error_code)
# --> 708             raise error_class(parsed_response, operation_name)
#     709         else:
#     710             return parsed_response
#
# ResourceLimitExceeded: An error occurred (ResourceLimitExceeded) when calling the CreateEndpoint operation: The account-level service limit 'Number of instances across active endpoints' is 2 Instances, with current utilization of 2 Instances and a request delta of 1 Instances. Please contact AWS support to request an increase for this limit.
